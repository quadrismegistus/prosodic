# %%
# !rm -rf /Users/ryan/prosodic_data/data/english_wordforms.sqlitedict
import sys; sys.path.insert(0,'..')
from prosodic.imports import *

# %%
# %%timeit
l = Text(sonnet)
l.df
# Out:
#                                                                             wordtoken_txt wordtype_txt  wordtype_num_forms  wordtype_num_sylls  wordtype_num_stressed_sylls wordform_sylls_ipa  \
# stanza_num line_num wordtoken_sent_num wordtoken_sentpart_num wordtoken_num
# 1          1        1                  1                      1                     Those        Those                   1                 1.0                          1.0            ['ðoʊz]
#                                                               2                     hours        hours                   2                 2.0                          1.0         ['aʊ, ɛːz]
#                                                               2                     hours        hours                   2                 2.0                          1.0         ['aʊ, ɛːz]
#                                                               2                     hours        hours                   2                 2.0                          1.0            ['aʊrz]
#                                                               3                         ,            ,                   0                 NaN                          NaN                NaN
# ...                                                                                   ...          ...                 ...                 ...                          ...                ...
#            14       1                  1                      7                 substance    substance                   1                 2.0                          1.0      ['sʌb, stəns]
#                                                               8                     still        still                   1                 1.0                          1.0            ['stɪl]
#                                                               9                     lives        lives                   1                 1.0                          1.0            ['lɪvz]
#                                                               10                    sweet        sweet                   1                 1.0                          1.0           ['swiːt]
#                                                               5                         .            .                   0                 NaN                          NaN                NaN
#
#                                                                             wordform_sylls_text wordform_token  syllable_num syllable_syll_ipa syllable_syll_stress wordtype_is_punc
# stanza_num line_num wordtoken_sent_num wordtoken_sentpart_num wordtoken_num
# 1          1        1                  1                      1                         [Those]          Those           1.0             'ðoʊz                    P              NaN
#                                                               2                       [ho, urs]          hours           1.0               'aʊ                    P              NaN
#                                                               2                       [ho, urs]          hours           2.0               ɛːz                    U              NaN
#                                                               2                         [hours]          hours           1.0             'aʊrz                    P              NaN
#                                                               3                             NaN            NaN           NaN               NaN                  NaN             True
# ...                                                                                         ...            ...           ...               ...                  ...              ...
#            14       1                  1                      7                   [subs, tance]      substance           2.0             stəns                    U              NaN
#                                                               8                         [still]          still           1.0             'stɪl                    P              NaN
#                                                               9                         [lives]          lives           1.0             'lɪvz                    P              NaN
#                                                               10                        [sweet]          sweet           1.0            'swiːt                    P              NaN
#                                                               5                             NaN            NaN           NaN               NaN                  NaN             True
#
# [208 rows x 12 columns]
