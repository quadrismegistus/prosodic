# %%
# !rm -rf /Users/ryan/prosodic_data/data/english_wordforms.sqlitedict
import sys; sys.path.insert(0,'..')
from prosodic.imports import *

# %%
x="""
Those hours, that with gentle work did frame
The lovely gaze where every eye doth dwell,
Will play the tyrants to the very same
And that unfair which fairly doth excel;
For never-resting time leads summer on
To hideous winter, and confounds him there;
Sap checked with frost, and lusty leaves quite gone,
Beauty o’er-snowed and bareness every where:
Then were not summer’s distillation left,
A liquid prisoner pent in walls of glass,
Beauty’s effect with beauty were bereft,
Nor it, nor no remembrance what it was:
But flowers distill’d, though they with winter meet,
Leese but their show; their substance still lives sweet.
"""

# %%
t=Text(x)
l = random.choice(t.lines)
l
# Out:
# (Line: Then were not summer's distillation left,) [sent_i=1           sentpart_i=9       stanza_i=1         line_i=10         ]

# %%
# %%timeit
l.parse(max_s=None, max_w=None)
# Out:
# 334 ms ± 2.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
l.parse(max_s=None, max_w=None)
l.bound_parses(l.all_parses)

# %%
# %%timeit -n 1 -r 1
l.bound_parses(poss_parses)
# Out:
# Scanning parses: 100%|██████████| 2048/2048 [00:00<00:00, 3566.11it/s]
# [(Parse: then.were.not.sum.mer's.dis.til.la.tion.left)             [rank=None          meter=----------   stress=+-++-+-+-+  score=21           is_bounded=True    w_peak=3           w_stress=6         unres_across=8     unres_within=4    ],
#  (Parse: THEN.WERE.NOT.SUM.MER'S.DIS.TIL.LA.TION.LEFT)             [rank=None          meter=++++++++++   stress=+-++-+-+-+  score=16           is_bounded=True    s_unstress=4       unres_across=8     unres_within=4    ],
#  (Parse: then|WERE.NOT.SUM.MER'S.DIS.TIL.LA.TION.LEFT)             [rank=None          meter=-+++++++++   stress=+-++-+-+-+  score=16           is_bounded=True    w_stress=1         s_unstress=4       unres_across=7     unres_within=4    ],
#  (Parse: then|WERE|not.sum.mer's.dis.til.la.tion.left)             [rank=None          meter=-+--------   stress=+-++-+-+-+  score=20           is_bounded=True    w_peak=3           w_stress=6         s_unstress=1       unres_across=6     unres_within=4    ],
#  (Parse: then|WERE|not|SUM.MER'S.DIS.TIL.LA.TION.LEFT)             [rank=None          meter=-+-+++++++   stress=+-++-+-+-+  score=14           is_bounded=True    w_stress=2         s_unstress=4       unres_across=4     unres_within=4    ],
#  (Parse: then|WERE|not|SUM|mer's.dis.til.la.tion.left)             [rank=None          meter=-+-+------   stress=+-++-+-+-+  score=15           is_bounded=True    w_peak=2           w_stress=5         s_unstress=1       unres_across=4     unres_within=3    ],
#  (Parse: then|WERE|not|SUM|mer's|DIS.TIL.LA.TION.LEFT)             [rank=None          meter=-+-+-+++++   stress=+-++-+-+-+  score=10           is_bounded=True    w_stress=2         s_unstress=3       unres_across=2     unres_within=3    ],
#  (Parse: then|WERE|not|SUM|mer's|DIS|til.la.tion.left)             [rank=None          meter=-+-+-+----   stress=+-++-+-+-+  score=10           is_bounded=True    w_peak=1           w_stress=4         s_unstress=1       unres_across=2     unres_within=2    ],
#  (Parse: then|WERE|not|SUM|mer's|DIS|til|LA.TION.LEFT)             [rank=None          meter=-+-+-+-+++   stress=+-++-+-+-+  score=7            is_bounded=True    w_stress=2         s_unstress=2       unres_across=2     unres_within=1    ],
#  (Parse: then|WERE|not|SUM|mer's|DIS|til|LA|tion.left)             [rank=None          meter=-+-+-+-+--   stress=+-++-+-+-+  score=6            is_bounded=True    w_stress=3         s_unstress=1       unres_across=2    ],
#  (Parse: then|WERE|not|SUM|mer's|DIS|til|LA|tion|LEFT)             [rank=None          meter=-+-+-+-+-+   stress=+-++-+-+-+  score=3            is_bounded=True    w_stress=2         s_unstress=1      ],
#  (Parse: then|WERE|not|SUM|mer's|DIS|til|LA.TION|left)             [rank=None          meter=-+-+-+-++-   stress=+-++-+-+-+  score=6            is_bounded=True    w_stress=3         s_unstress=2       unres_within=1    ],
#  (Parse: then|WERE|not|SUM|mer's|DIS|til.la|TION.LEFT)             [rank=None          meter=-+-+-+--++   stress=+-++-+-+-+  score=9            is_bounded=True    w_peak=1           w_stress=3         s_unstress=2       unres_across=2     unres_within=1    ],
#  (Parse: then|WERE|not|SUM|mer's|DIS|til.la|TION|left)             [rank=None          meter=-+-+-+--+-   stress=+-++-+-+-+  score=8            is_bounded=True    w_peak=1           w_stress=4         s_unstress=2       unres_within=1    ],
#  (Parse: then|WERE|not|SUM|mer's|DIS|til.la.tion|LEFT)             [rank=None          meter=-+-+-+---+   stress=+-++-+-+-+  score=7            is_bounded=True    w_peak=1           w_stress=3         s_unstress=1       unres_within=2    ],
#  (Parse: then|WERE|not|SUM|mer's|DIS.TIL|la.tion.left)             [rank=None          meter=-+-+-++---   stress=+-++-+-+-+  score=11           is_bounded=True    w_peak=1           w_stress=4         s_unstress=2       unres_across=2     unres_within=2    ],
#  (Parse: then|WERE|not|SUM|mer's|DIS.TIL|la|TION.LEFT)             [rank=None          meter=-+-+-++-++   stress=+-++-+-+-+  score=10           is_bounded=True    w_peak=1           w_stress=3         s_unstress=3       unres_across=2     unres_within=1    ],
#  (Parse: then|WERE|not|SUM|mer's|DIS.TIL|la|TION|left)             [rank=None          meter=-+-+-++-+-   stress=+-++-+-+-+  score=9            is_bounded=True    w_peak=1           w_stress=4         s_unstress=3       unres_within=1    ],
#  (Parse: then|WERE|not|SUM|mer's|DIS.TIL|la.tion|LEFT)             [rank=None          meter=-+-+-++--+   stress=+-++-+-+-+  score=8            is_bounded=True    w_peak=1           w_stress=3         s_unstress=2       unres_within=2    ],
#  (Parse: then|WERE|not|SUM|mer's|DIS.TIL.LA|tion.left)             [rank=None          meter=-+-+-+++--   stress=+-++-+-+-+  score=9            is_bounded=True    w_stress=3         s_unstress=2       unres_across=2     unres_within=2    ],
#  (Parse: then|WERE|not|SUM|mer's|DIS.TIL.LA|tion|LEFT)             [rank=None          meter=-+-+-+++-+   stress=+-++-+-+-+  score=6            is_bounded=True    w_stress=2         s_unstress=2       unres_within=2    ],
#  (Parse: then|WERE|not|SUM|mer's|DIS.TIL.LA.TION|left)             [rank=None          meter=-+-+-++++-   stress=+-++-+-+-+  score=9            is_bounded=True    w_stress=3         s_unstress=3       unres_within=3    ],
#  (Parse: then|WERE|not|SUM|mer's.dis|TIL.LA.TION.LEFT)             [rank=None          meter=-+-+--++++   stress=+-++-+-+-+  score=13           is_bounded=True    w_peak=1           w_stress=3         s_unstress=3       unres_across=4     unres_within=2    ],
#  (Parse: then|WERE|not|SUM|mer's.dis|TIL|la.tion.left)             [rank=None          meter=-+-+--+---   stress=+-++-+-+-+  score=14           is_bounded=True    w_peak=2           w_stress=5         s_unstress=2       unres_across=4     unres_within=1    ],
#  (Parse: then|WERE|not|SUM|mer's.dis|TIL|la|TION.LEFT)             [rank=None          meter=-+-+--+-++   stress=+-++-+-+-+  score=13           is_bounded=True    w_peak=2           w_stress=4         s_unstress=3       unres_across=4    ],
#  (Parse: then|WERE|not|SUM|mer's.dis|TIL|la|TION|left)             [rank=None          meter=-+-+--+-+-   stress=+-++-+-+-+  score=12           is_bounded=True    w_peak=2           w_stress=5         s_unstress=3       unres_across=2    ],
#  (Parse: then|WERE|not|SUM|mer's.dis|TIL|la.tion|LEFT)             [rank=None          meter=-+-+--+--+   stress=+-++-+-+-+  score=11           is_bounded=True    w_peak=2           w_stress=4         s_unstress=2       unres_across=2     unres_within=1    ],
#  (Parse: then|WERE|not|SUM|mer's.dis|TIL.LA|tion.left)             [rank=None          meter=-+-+--++--   stress=+-++-+-+-+  score=12           is_bounded=True    w_peak=1           w_stress=4         s_unstress=2       unres_across=4     unres_within=1    ],
#  (Parse: then|WERE|not|SUM|mer's.dis|TIL.LA|tion|LEFT)             [rank=None          meter=-+-+--++-+   stress=+-++-+-+-+  score=9            is_bounded=True    w_peak=1           w_stress=3         s_unstress=2       unres_across=2     unres_within=1    ],
#  (Parse: then|WERE|not|SUM|mer's.dis|TIL.LA.TION|left)             [rank=None          meter=-+-+--+++-   stress=+-++-+-+-+  score=12           is_bounded=True    w_peak=1           w_stress=4         s_unstress=3       unres_across=2     unres_within=2    ],
#  (Parse: then|WERE|not|SUM|mer's.dis.til|LA.TION.LEFT)             [rank=None          meter=-+-+---+++   stress=+-++-+-+-+  score=12           is_bounded=True    w_peak=1           w_stress=3         s_unstress=2       unres_across=4     unres_within=2    ],
#  (Parse: then|WERE|not|SUM|mer's.dis.til|LA|tion.left)             [rank=None          meter=-+-+---+--   stress=+-++-+-+-+  score=11           is_bounded=True    w_peak=1           w_stress=4         s_unstress=1       unres_across=4     unres_within=1    ],
#  (Parse: then|WERE|not|SUM|mer's.dis.til|LA|tion|LEFT)             [rank=None          meter=-+-+---+-+   stress=+-++-+-+-+  score=8            is_bounded=True    w_peak=1           w_stress=3         s_unstress=1       unres_across=2     unres_within=1    ],
#  (Parse: then|WERE|not|SUM|mer's.dis.til|LA.TION|left)             [rank=None          meter=-+-+---++-   stress=+-++-+-+-+  score=11           is_bounded=True    w_peak=1           w_stress=4         s_unstress=2       unres_across=2     unres_within=2    ],
#  (Parse: then|WERE|not|SUM|mer's.dis.til.la|TION.LEFT)             [rank=None          meter=-+-+----++   stress=+-++-+-+-+  score=14           is_bounded=True    w_peak=2           w_stress=4         s_unstress=2       unres_across=4     unres_within=2    ],
#  (Parse: then|WERE|not|SUM|mer's.dis.til.la|TION|left)             [rank=None          meter=-+-+----+-   stress=+-++-+-+-+  score=13           is_bounded=True    w_peak=2           w_stress=5         s_unstress=2       unres_across=2     unres_within=2    ],
#  (Parse: then|WERE|not|SUM|mer's.dis.til.la.tion|LEFT)             [rank=None          meter=-+-+-----+   stress=+-++-+-+-+  score=12           is_bounded=True    w_peak=2           w_stress=4         s_unstress=1       unres_across=2     unres_within=3    ],
#  (Parse: then|WERE|not|SUM.MER'S|dis.til.la.tion.left)             [rank=None          meter=-+-++-----   stress=+-++-+-+-+  score=15           is_bounded=True    w_peak=2           w_stress=5         s_unstress=2       unres_across=2     unres_within=4    ],
#  (Parse: then|WERE|not|SUM.MER'S|dis|TIL.LA.TION.LEFT)             [rank=None          meter=-+-++-++++   stress=+-++-+-+-+  score=13           is_bounded=True    w_peak=1           w_stress=3         s_unstress=4       unres_across=2     unres_within=3    ],
#  (Parse: then|WERE|not|SUM.MER'S|dis|TIL|la.tion.left)             [rank=None          meter=-+-++-+---   stress=+-++-+-+-+  score=14           is_bounded=True    w_peak=2           w_stress=5         s_unstress=3       unres_across=2     unres_within=2    ],
#  (Parse: then|WERE|not|SUM.MER'S|dis|TIL|la|TION.LEFT)             [rank=None          meter=-+-++-+-++   stress=+-++-+-+-+  score=13           is_bounded=True    w_peak=2           w_stress=4         s_unstress=4       unres_across=2     unres_within=1    ],
#  (Parse: then|WERE|not|SUM.MER'S|dis|TIL|la|TION|left)             [rank=None          meter=-+-++-+-+-   stress=+-++-+-+-+  score=12           is_bounded=True    w_peak=2           w_stress=5         s_unstress=4       unres_within=1    ],
#  (Parse: then|WERE|not|SUM.MER'S|dis|TIL|la.tion|LEFT)             [rank=None          meter=-+-++-+--+   stress=+-++-+-+-+  score=11           is_bounded=True    w_peak=2           w_stress=4         s_unstress=3       unres_within=2    ],
#  (Parse: then|WERE|not|SUM.MER'S|dis|TIL.LA|tion.left)             [rank=None          meter=-+-++-++--   stress=+-++-+-+-+  score=12           is_bounded=True    w_peak=1           w_stress=4         s_unstress=3       unres_across=2     unres_within=2    ],
#  (Parse: then|WERE|not|SUM.MER'S|dis|TIL.LA|tion|LEFT)             [rank=None          meter=-+-++-++-+   stress=+-++-+-+-+  score=9            is_bounded=True    w_peak=1           w_stress=3         s_unstress=3       unres_within=2    ],
#  (Parse: then|WERE|not|SUM.MER'S|dis|TIL.LA.TION|left)             [rank=None          meter=-+-++-+++-   stress=+-++-+-+-+  score=12           is_bounded=True    w_peak=1           w_stress=4         s_unstress=4       unres_within=3    ],
#  (Parse: then|WERE|not|SUM.MER'S|dis.til|LA.TION.LEFT)             [rank=None          meter=-+-++--+++   stress=+-++-+-+-+  score=12           is_bounded=True    w_peak=1           w_stress=3         s_unstress=3       unres_across=2     unres_within=3    ],
#  (Parse: then|WERE|not|SUM.MER'S|dis.til|LA|tion.left)             [rank=None          meter=-+-++--+--   stress=+-++-+-+-+  score=11           is_bounded=True    w_peak=1           w_stress=4         s_unstress=2       unres_across=2     unres_within=2    ],
#  (Parse: then|WERE|not|SUM.MER'S|dis.til|LA|tion|LEFT)             [rank=None          meter=-+-++--+-+   stress=+-++-+-+-+  score=8            is_bounded=True    w_peak=1           w_stress=3         s_unstress=2       unres_within=2    ],
#  (Parse: then|WERE|not|SUM.MER'S|dis.til|LA.TION|left)             [rank=None          meter=-+-++--++-   stress=+-++-+-+-+  score=11           is_bounded=True    w_peak=1           w_stress=4         s_unstress=3       unres_within=3    ],
#  (Parse: then|WERE|not|SUM.MER'S|dis.til.la|TION.LEFT)             [rank=None          meter=-+-++---++   stress=+-++-+-+-+  score=14           is_bounded=True    w_peak=2           w_stress=4         s_unstress=3       unres_across=2     unres_within=3    ],
#  (Parse: then|WERE|not|SUM.MER'S|dis.til.la|TION|left)             [rank=None          meter=-+-++---+-   stress=+-++-+-+-+  score=13           is_bounded=True    w_peak=2           w_stress=5         s_unstress=3       unres_within=3    ],
#  (Parse: then|WERE|not|SUM.MER'S|dis.til.la.tion|LEFT)             [rank=None          meter=-+-++----+   stress=+-++-+-+-+  score=12           is_bounded=True    w_peak=2           w_stress=4         s_unstress=2       unres_within=4    ],
#  (Parse: then|WERE|not|SUM.MER'S.DIS|til.la.tion.left)             [rank=None          meter=-+-+++----   stress=+-++-+-+-+  score=14           is_bounded=True    w_peak=1           w_stress=4         s_unstress=2       unres_across=4     unres_within=3    ],
#  (Parse: then|WERE|not|SUM.MER'S.DIS|til|LA.TION.LEFT)             [rank=None          meter=-+-+++-+++   stress=+-++-+-+-+  score=11           is_bounded=True    w_stress=2         s_unstress=3       unres_across=4     unres_within=2    ],
#  (Parse: then|WERE|not|SUM.MER'S.DIS|til|LA|tion.left)             [rank=None          meter=-+-+++-+--   stress=+-++-+-+-+  score=10           is_bounded=True    w_stress=3         s_unstress=2       unres_across=4     unres_within=1    ],
#  (Parse: then|WERE|not|SUM.MER'S.DIS|til|LA|tion|LEFT)             [rank=None          meter=-+-+++-+-+   stress=+-++-+-+-+  score=7            is_bounded=True    w_stress=2         s_unstress=2       unres_across=2     unres_within=1    ],
#  (Parse: then|WERE|not|SUM.MER'S.DIS|til|LA.TION|left)             [rank=None          meter=-+-+++-++-   stress=+-++-+-+-+  score=10           is_bounded=True    w_stress=3         s_unstress=3       unres_across=2     unres_within=2    ],
#  (Parse: then|WERE|not|SUM.MER'S.DIS|til.la|TION.LEFT)             [rank=None          meter=-+-+++--++   stress=+-++-+-+-+  score=13           is_bounded=True    w_peak=1           w_stress=3         s_unstress=3       unres_across=4     unres_within=2    ],
#  (Parse: then|WERE|not|SUM.MER'S.DIS|til.la|TION|left)             [rank=None          meter=-+-+++--+-   stress=+-++-+-+-+  score=12           is_bounded=True    w_peak=1           w_stress=4         s_unstress=3       unres_across=2     unres_within=2    ],
#  (Parse: then|WERE|not|SUM.MER'S.DIS|til.la.tion|LEFT)             [rank=None          meter=-+-+++---+   stress=+-++-+-+-+  score=11           is_bounded=True    w_peak=1           w_stress=3         s_unstress=2       unres_across=2     unres_within=3    ],
#  (Parse: then|WERE|not|SUM.MER'S.DIS.TIL|la.tion.left)             [rank=None          meter=-+-++++---   stress=+-++-+-+-+  score=15           is_bounded=True    w_peak=1           w_stress=4         s_unstress=3       unres_across=4     unres_within=3    ],
#  (Parse: then|WERE|not|SUM.MER'S.DIS.TIL|la|TION.LEFT)             [rank=None          meter=-+-++++-++   stress=+-++-+-+-+  score=14           is_bounded=True    w_peak=1           w_stress=3         s_unstress=4       unres_across=4     unres_within=2    ],
#  (Parse: then|WERE|not|SUM.MER'S.DIS.TIL|la|TION|left)             [rank=None          meter=-+-++++-+-   stress=+-++-+-+-+  score=13           is_bounded=True    w_peak=1           w_stress=4         s_unstress=4       unres_across=2     unres_within=2    ],
#  (Parse: then|WERE|not|SUM.MER'S.DIS.TIL|la.tion|LEFT)             [rank=None          meter=-+-++++--+   stress=+-++-+-+-+  score=12           is_bounded=True    w_peak=1           w_stress=3         s_unstress=3       unres_across=2     unres_within=3    ],
#  (Parse: then|WERE|not|SUM.MER'S.DIS.TIL.LA|tion.left)             [rank=None          meter=-+-+++++--   stress=+-++-+-+-+  score=13           is_bounded=True    w_stress=3         s_unstress=3       unres_across=4     unres_within=3    ],
#  (Parse: then|WERE|not|SUM.MER'S.DIS.TIL.LA|tion|LEFT)             [rank=None          meter=-+-+++++-+   stress=+-++-+-+-+  score=10           is_bounded=True    w_stress=2         s_unstress=3       unres_across=2     unres_within=3    ],
#  (Parse: then|WERE|not|SUM.MER'S.DIS.TIL.LA.TION|left)             [rank=None          meter=-+-++++++-   stress=+-++-+-+-+  score=13           is_bounded=True    w_stress=3         s_unstress=4       unres_across=2     unres_within=4    ],
#  (Parse: then|WERE|not.sum|MER'S.DIS.TIL.LA.TION.LEFT)             [rank=None          meter=-+--++++++   stress=+-++-+-+-+  score=17           is_bounded=True    w_peak=1           w_stress=3         s_unstress=4       unres_across=6     unres_within=3    ],
#  (Parse: then|WERE|not.sum|MER'S|dis.til.la.tion.left)             [rank=None          meter=-+--+-----   stress=+-++-+-+-+  score=18           is_bounded=True    w_peak=3           w_stress=6         s_unstress=2       unres_across=4     unres_within=3    ],
#  (Parse: then|WERE|not.sum|MER'S|dis|TIL.LA.TION.LEFT)             [rank=None          meter=-+--+-++++   stress=+-++-+-+-+  score=16           is_bounded=True    w_peak=2           w_stress=4         s_unstress=4       unres_across=4     unres_within=2    ],
#  (Parse: then|WERE|not.sum|MER'S|dis|TIL|la.tion.left)             [rank=None          meter=-+--+-+---   stress=+-++-+-+-+  score=17           is_bounded=True    w_peak=3           w_stress=6         s_unstress=3       unres_across=4     unres_within=1    ],
#  (Parse: then|WERE|not.sum|MER'S|dis|TIL|la|TION.LEFT)             [rank=None          meter=-+--+-+-++   stress=+-++-+-+-+  score=16           is_bounded=True    w_peak=3           w_stress=5         s_unstress=4       unres_across=4    ],
#  (Parse: then|WERE|not.sum|MER'S|dis|TIL|la|TION|left)             [rank=None          meter=-+--+-+-+-   stress=+-++-+-+-+  score=15           is_bounded=True    w_peak=3           w_stress=6         s_unstress=4       unres_across=2    ],
#  (Parse: then|WERE|not.sum|MER'S|dis|TIL|la.tion|LEFT)             [rank=None          meter=-+--+-+--+   stress=+-++-+-+-+  score=14           is_bounded=True    w_peak=3           w_stress=5         s_unstress=3       unres_across=2     unres_within=1    ],
#  (Parse: then|WERE|not.sum|MER'S|dis|TIL.LA|tion.left)             [rank=None          meter=-+--+-++--   stress=+-++-+-+-+  score=15           is_bounded=True    w_peak=2           w_stress=5         s_unstress=3       unres_across=4     unres_within=1    ],
#  (Parse: then|WERE|not.sum|MER'S|dis|TIL.LA|tion|LEFT)             [rank=None          meter=-+--+-++-+   stress=+-++-+-+-+  score=12           is_bounded=True    w_peak=2           w_stress=4         s_unstress=3       unres_across=2     unres_within=1    ],
#  (Parse: then|WERE|not.sum|MER'S|dis|TIL.LA.TION|left)             [rank=None          meter=-+--+-+++-   stress=+-++-+-+-+  score=15           is_bounded=True    w_peak=2           w_stress=5         s_unstress=4       unres_across=2     unres_within=2    ],
#  (Parse: then|WERE|not.sum|MER'S|dis.til|LA.TION.LEFT)             [rank=None          meter=-+--+--+++   stress=+-++-+-+-+  score=15           is_bounded=True    w_peak=2           w_stress=4         s_unstress=3       unres_across=4     unres_within=2    ],
#  (Parse: then|WERE|not.sum|MER'S|dis.til|LA|tion.left)             [rank=None          meter=-+--+--+--   stress=+-++-+-+-+  score=14           is_bounded=True    w_peak=2           w_stress=5         s_unstress=2       unres_across=4     unres_within=1    ],
#  (Parse: then|WERE|not.sum|MER'S|dis.til|LA|tion|LEFT)             [rank=None          meter=-+--+--+-+   stress=+-++-+-+-+  score=11           is_bounded=True    w_peak=2           w_stress=4         s_unstress=2       unres_across=2     unres_within=1    ],
#  (Parse: then|WERE|not.sum|MER'S|dis.til|LA.TION|left)             [rank=None          meter=-+--+--++-   stress=+-++-+-+-+  score=14           is_bounded=True    w_peak=2           w_stress=5         s_unstress=3       unres_across=2     unres_within=2    ],
#  (Parse: then|WERE|not.sum|MER'S|dis.til.la|TION.LEFT)             [rank=None          meter=-+--+---++   stress=+-++-+-+-+  score=17           is_bounded=True    w_peak=3           w_stress=5         s_unstress=3       unres_across=4     unres_within=2    ],
#  (Parse: then|WERE|not.sum|MER'S|dis.til.la|TION|left)             [rank=None          meter=-+--+---+-   stress=+-++-+-+-+  score=16           is_bounded=True    w_peak=3           w_stress=6         s_unstress=3       unres_across=2     unres_within=2    ],
#  (Parse: then|WERE|not.sum|MER'S|dis.til.la.tion|LEFT)             [rank=None          meter=-+--+----+   stress=+-++-+-+-+  score=15           is_bounded=True    w_peak=3           w_stress=5         s_unstress=2       unres_across=2     unres_within=3    ],
#  (Parse: then|WERE|not.sum|MER'S.DIS|til.la.tion.left)             [rank=None          meter=-+--++----   stress=+-++-+-+-+  score=17           is_bounded=True    w_peak=2           w_stress=5         s_unstress=2       unres_across=6     unres_within=2    ],
#  (Parse: then|WERE|not.sum|MER'S.DIS|til|LA.TION.LEFT)             [rank=None          meter=-+--++-+++   stress=+-++-+-+-+  score=14           is_bounded=True    w_peak=1           w_stress=3         s_unstress=3       unres_across=6     unres_within=1    ],
#  (Parse: then|WERE|not.sum|MER'S.DIS|til|LA|tion.left)             [rank=None          meter=-+--++-+--   stress=+-++-+-+-+  score=13           is_bounded=True    w_peak=1           w_stress=4         s_unstress=2       unres_across=6    ],
#  (Parse: then|WERE|not.sum|MER'S.DIS|til|LA|tion|LEFT)             [rank=None          meter=-+--++-+-+   stress=+-++-+-+-+  score=10           is_bounded=True    w_peak=1           w_stress=3         s_unstress=2       unres_across=4    ],
#  (Parse: then|WERE|not.sum|MER'S.DIS|til|LA.TION|left)             [rank=None          meter=-+--++-++-   stress=+-++-+-+-+  score=13           is_bounded=True    w_peak=1           w_stress=4         s_unstress=3       unres_across=4     unres_within=1    ],
#  (Parse: then|WERE|not.sum|MER'S.DIS|til.la|TION.LEFT)             [rank=None          meter=-+--++--++   stress=+-++-+-+-+  score=16           is_bounded=True    w_peak=2           w_stress=4         s_unstress=3       unres_across=6     unres_within=1    ],
#  (Parse: then|WERE|not.sum|MER'S.DIS|til.la|TION|left)             [rank=None          meter=-+--++--+-   stress=+-++-+-+-+  score=15           is_bounded=True    w_peak=2           w_stress=5         s_unstress=3       unres_across=4     unres_within=1    ],
#  (Parse: then|WERE|not.sum|MER'S.DIS|til.la.tion|LEFT)             [rank=None          meter=-+--++---+   stress=+-++-+-+-+  score=14           is_bounded=True    w_peak=2           w_stress=4         s_unstress=2       unres_across=4     unres_within=2    ],
#  (Parse: then|WERE|not.sum|MER'S.DIS.TIL|la.tion.left)             [rank=None          meter=-+--+++---   stress=+-++-+-+-+  score=18           is_bounded=True    w_peak=2           w_stress=5         s_unstress=3       unres_across=6     unres_within=2    ],
#  (Parse: then|WERE|not.sum|MER'S.DIS.TIL|la|TION.LEFT)             [rank=None          meter=-+--+++-++   stress=+-++-+-+-+  score=17           is_bounded=True    w_peak=2           w_stress=4         s_unstress=4       unres_across=6     unres_within=1    ],
#  (Parse: then|WERE|not.sum|MER'S.DIS.TIL|la|TION|left)             [rank=None          meter=-+--+++-+-   stress=+-++-+-+-+  score=16           is_bounded=True    w_peak=2           w_stress=5         s_unstress=4       unres_across=4     unres_within=1    ],
#  (Parse: then|WERE|not.sum|MER'S.DIS.TIL|la.tion|LEFT)             [rank=None          meter=-+--+++--+   stress=+-++-+-+-+  score=15           is_bounded=True    w_peak=2           w_stress=4         s_unstress=3       unres_across=4     unres_within=2    ],
#  (Parse: then|WERE|not.sum|MER'S.DIS.TIL.LA|tion.left)             [rank=None          meter=-+--++++--   stress=+-++-+-+-+  score=16           is_bounded=True    w_peak=1           w_stress=4         s_unstress=3       unres_across=6     unres_within=2    ],
#  (Parse: then|WERE|not.sum|MER'S.DIS.TIL.LA|tion|LEFT)             [rank=None          meter=-+--++++-+   stress=+-++-+-+-+  score=13           is_bounded=True    w_peak=1           w_stress=3         s_unstress=3       unres_across=4     unres_within=2    ],
#  (Parse: then|WERE|not.sum|MER'S.DIS.TIL.LA.TION|left)             [rank=None          meter=-+--+++++-   stress=+-++-+-+-+  score=16           is_bounded=True    w_peak=1           w_stress=4         s_unstress=4       unres_across=4     unres_within=3    ],
#  (Parse: then|WERE|not.sum.mer's|DIS.TIL.LA.TION.LEFT)             [rank=None          meter=-+---+++++   stress=+-++-+-+-+  score=15           is_bounded=True    w_peak=1           w_stress=3         s_unstress=3       unres_across=4     unres_within=4    ],
#  (Parse: then|WERE|not.sum.mer's|DIS|til.la.tion.left)             [rank=None          meter=-+---+----   stress=+-++-+-+-+  score=15           is_bounded=True    w_peak=2           w_stress=5         s_unstress=1       unres_across=4     unres_within=3    ],
#  (Parse: then|WERE|not.sum.mer's|DIS|til|LA.TION.LEFT)             [rank=None          meter=-+---+-+++   stress=+-++-+-+-+  score=12           is_bounded=True    w_peak=1           w_stress=3         s_unstress=2       unres_across=4     unres_within=2    ],
#  (Parse: then|WERE|not.sum.mer's|DIS|til|LA|tion.left)             [rank=None          meter=-+---+-+--   stress=+-++-+-+-+  score=11           is_bounded=True    w_peak=1           w_stress=4         s_unstress=1       unres_across=4     unres_within=1    ],
#  (Parse: then|WERE|not.sum.mer's|DIS|til|LA|tion|LEFT)             [rank=None          meter=-+---+-+-+   stress=+-++-+-+-+  score=8            is_bounded=True    w_peak=1           w_stress=3         s_unstress=1       unres_across=2     unres_within=1    ],
#  (Parse: then|WERE|not.sum.mer's|DIS|til|LA.TION|left)             [rank=None          meter=-+---+-++-   stress=+-++-+-+-+  score=11           is_bounded=True    w_peak=1           w_stress=4         s_unstress=2       unres_across=2     unres_within=2    ],
#  (Parse: then|WERE|not.sum.mer's|DIS|til.la|TION.LEFT)             [rank=None          meter=-+---+--++   stress=+-++-+-+-+  score=14           is_bounded=True    w_peak=2           w_stress=4         s_unstress=2       unres_across=4     unres_within=2    ],
#  (Parse: then|WERE|not.sum.mer's|DIS|til.la|TION|left)             [rank=None          meter=-+---+--+-   stress=+-++-+-+-+  score=13           is_bounded=True    w_peak=2           w_stress=5         s_unstress=2       unres_across=2     unres_within=2    ],
#  (Parse: then|WERE|not.sum.mer's|DIS|til.la.tion|LEFT)             [rank=None          meter=-+---+---+   stress=+-++-+-+-+  score=12           is_bounded=True    w_peak=2           w_stress=4         s_unstress=1       unres_across=2     unres_within=3    ],
#  (Parse: then|WERE|not.sum.mer's|DIS.TIL|la.tion.left)             [rank=None          meter=-+---++---   stress=+-++-+-+-+  score=16           is_bounded=True    w_peak=2           w_stress=5         s_unstress=2       unres_across=4     unres_within=3    ],
#  (Parse: then|WERE|not.sum.mer's|DIS.TIL|la|TION.LEFT)             [rank=None          meter=-+---++-++   stress=+-++-+-+-+  score=15           is_bounded=True    w_peak=2           w_stress=4         s_unstress=3       unres_across=4     unres_within=2    ],
#  (Parse: then|WERE|not.sum.mer's|DIS.TIL|la|TION|left)             [rank=None          meter=-+---++-+-   stress=+-++-+-+-+  score=14           is_bounded=True    w_peak=2           w_stress=5         s_unstress=3       unres_across=2     unres_within=2    ],
#  (Parse: then|WERE|not.sum.mer's|DIS.TIL|la.tion|LEFT)             [rank=None          meter=-+---++--+   stress=+-++-+-+-+  score=13           is_bounded=True    w_peak=2           w_stress=4         s_unstress=2       unres_across=2     unres_within=3    ],
#  (Parse: then|WERE|not.sum.mer's|DIS.TIL.LA|tion.left)             [rank=None          meter=-+---+++--   stress=+-++-+-+-+  score=14           is_bounded=True    w_peak=1           w_stress=4         s_unstress=2       unres_across=4     unres_within=3    ],
#  (Parse: then|WERE|not.sum.mer's|DIS.TIL.LA|tion|LEFT)             [rank=None          meter=-+---+++-+   stress=+-++-+-+-+  score=11           is_bounded=True    w_peak=1           w_stress=3         s_unstress=2       unres_across=2     unres_within=3    ],
#  (Parse: then|WERE|not.sum.mer's|DIS.TIL.LA.TION|left)             [rank=None          meter=-+---++++-   stress=+-++-+-+-+  score=14           is_bounded=True    w_peak=1           w_stress=4         s_unstress=3       unres_across=2     unres_within=4    ],
#  (Parse: then|WERE|not.sum.mer's.dis|TIL.LA.TION.LEFT)             [rank=None          meter=-+----++++   stress=+-++-+-+-+  score=18           is_bounded=True    w_peak=2           w_stress=4         s_unstress=3       unres_across=6     unres_within=3    ],
#  (Parse: then|WERE|not.sum.mer's.dis|TIL|la.tion.left)             [rank=None          meter=-+----+---   stress=+-++-+-+-+  score=19           is_bounded=True    w_peak=3           w_stress=6         s_unstress=2       unres_across=6     unres_within=2    ],
#  (Parse: then|WERE|not.sum.mer's.dis|TIL|la|TION.LEFT)             [rank=None          meter=-+----+-++   stress=+-++-+-+-+  score=18           is_bounded=True    w_peak=3           w_stress=5         s_unstress=3       unres_across=6     unres_within=1    ],
#  (Parse: then|WERE|not.sum.mer's.dis|TIL|la|TION|left)             [rank=None          meter=-+----+-+-   stress=+-++-+-+-+  score=17           is_bounded=True    w_peak=3           w_stress=6         s_unstress=3       unres_across=4     unres_within=1    ],
#  (Parse: then|WERE|not.sum.mer's.dis|TIL|la.tion|LEFT)             [rank=None          meter=-+----+--+   stress=+-++-+-+-+  score=16           is_bounded=True    w_peak=3           w_stress=5         s_unstress=2       unres_across=4     unres_within=2    ],
#  (Parse: then|WERE|not.sum.mer's.dis|TIL.LA|tion.left)             [rank=None          meter=-+----++--   stress=+-++-+-+-+  score=17           is_bounded=True    w_peak=2           w_stress=5         s_unstress=2       unres_across=6     unres_within=2    ],
#  (Parse: then|WERE|not.sum.mer's.dis|TIL.LA|tion|LEFT)             [rank=None          meter=-+----++-+   stress=+-++-+-+-+  score=14           is_bounded=True    w_peak=2           w_stress=4         s_unstress=2       unres_across=4     unres_within=2    ],
#  (Parse: then|WERE|not.sum.mer's.dis|TIL.LA.TION|left)             [rank=None          meter=-+----+++-   stress=+-++-+-+-+  score=17           is_bounded=True    w_peak=2           w_stress=5         s_unstress=3       unres_across=4     unres_within=3    ],
#  (Parse: then|WERE|not.sum.mer's.dis.til|LA.TION.LEFT)             [rank=None          meter=-+-----+++   stress=+-++-+-+-+  score=17           is_bounded=True    w_peak=2           w_stress=4         s_unstress=2       unres_across=6     unres_within=3    ],
#  (Parse: then|WERE|not.sum.mer's.dis.til|LA|tion.left)             [rank=None          meter=-+-----+--   stress=+-++-+-+-+  score=16           is_bounded=True    w_peak=2           w_stress=5         s_unstress=1       unres_across=6     unres_within=2    ],
#  (Parse: then|WERE|not.sum.mer's.dis.til|LA|tion|LEFT)             [rank=None          meter=-+-----+-+   stress=+-++-+-+-+  score=13           is_bounded=True    w_peak=2           w_stress=4         s_unstress=1       unres_across=4     unres_within=2    ],
#  (Parse: then|WERE|not.sum.mer's.dis.til|LA.TION|left)             [rank=None          meter=-+-----++-   stress=+-++-+-+-+  score=16           is_bounded=True    w_peak=2           w_stress=5         s_unstress=2       unres_across=4     unres_within=3    ],
#  (Parse: then|WERE|not.sum.mer's.dis.til.la|TION.LEFT)             [rank=None          meter=-+------++   stress=+-++-+-+-+  score=19           is_bounded=True    w_peak=3           w_stress=5         s_unstress=2       unres_across=6     unres_within=3    ],
#  (Parse: then|WERE|not.sum.mer's.dis.til.la|TION|left)             [rank=None          meter=-+------+-   stress=+-++-+-+-+  score=18           is_bounded=True    w_peak=3           w_stress=6         s_unstress=2       unres_across=4     unres_within=3    ],
#  (Parse: then|WERE|not.sum.mer's.dis.til.la.tion|LEFT)             [rank=None          meter=-+-------+   stress=+-++-+-+-+  score=17           is_bounded=True    w_peak=3           w_stress=5         s_unstress=1       unres_across=4     unres_within=4    ],
#  (Parse: then|WERE.NOT|sum.mer's.dis.til.la.tion.left)             [rank=None          meter=-++-------   stress=+-++-+-+-+  score=19           is_bounded=True    w_peak=3           w_stress=5         s_unstress=1       unres_across=6     unres_within=4    ],
#  (Parse: then|WERE.NOT|sum|MER'S.DIS.TIL.LA.TION.LEFT)             [rank=None          meter=-++-++++++   stress=+-++-+-+-+  score=16           is_bounded=True    w_peak=1           w_stress=2         s_unstress=4       unres_across=6     unres_within=3    ],
#  (Parse: then|WERE.NOT|sum|MER'S|dis.til.la.tion.left)             [rank=None          meter=-++-+-----   stress=+-++-+-+-+  score=17           is_bounded=True    w_peak=3           w_stress=5         s_unstress=2       unres_across=4     unres_within=3    ],
#  (Parse: then|WERE.NOT|sum|MER'S|dis|TIL.LA.TION.LEFT)             [rank=None          meter=-++-+-++++   stress=+-++-+-+-+  score=15           is_bounded=True    w_peak=2           w_stress=3         s_unstress=4       unres_across=4     unres_within=2    ],
#  (Parse: then|WERE.NOT|sum|MER'S|dis|TIL|la.tion.left)             [rank=None          meter=-++-+-+---   stress=+-++-+-+-+  score=16           is_bounded=True    w_peak=3           w_stress=5         s_unstress=3       unres_across=4     unres_within=1    ],
#  (Parse: then|WERE.NOT|sum|MER'S|dis|TIL|la|TION.LEFT)             [rank=None          meter=-++-+-+-++   stress=+-++-+-+-+  score=15           is_bounded=True    w_peak=3           w_stress=4         s_unstress=4       unres_across=4    ],
#  (Parse: then|WERE.NOT|sum|MER'S|dis|TIL|la|TION|left)             [rank=None          meter=-++-+-+-+-   stress=+-++-+-+-+  score=14           is_bounded=True    w_peak=3           w_stress=5         s_unstress=4       unres_across=2    ],
#  (Parse: then|WERE.NOT|sum|MER'S|dis|TIL|la.tion|LEFT)             [rank=None          meter=-++-+-+--+   stress=+-++-+-+-+  score=13           is_bounded=True    w_peak=3           w_stress=4         s_unstress=3       unres_across=2     unres_within=1    ],
#  (Parse: then|WERE.NOT|sum|MER'S|dis|TIL.LA|tion.left)             [rank=None          meter=-++-+-++--   stress=+-++-+-+-+  score=14           is_bounded=True    w_peak=2           w_stress=4         s_unstress=3       unres_across=4     unres_within=1    ],
#  (Parse: then|WERE.NOT|sum|MER'S|dis|TIL.LA|tion|LEFT)             [rank=None          meter=-++-+-++-+   stress=+-++-+-+-+  score=11           is_bounded=True    w_peak=2           w_stress=3         s_unstress=3       unres_across=2     unres_within=1    ],
#  (Parse: then|WERE.NOT|sum|MER'S|dis|TIL.LA.TION|left)             [rank=None          meter=-++-+-+++-   stress=+-++-+-+-+  score=14           is_bounded=True    w_peak=2           w_stress=4         s_unstress=4       unres_across=2     unres_within=2    ],
#  (Parse: then|WERE.NOT|sum|MER'S|dis.til|LA.TION.LEFT)             [rank=None          meter=-++-+--+++   stress=+-++-+-+-+  score=14           is_bounded=True    w_peak=2           w_stress=3         s_unstress=3       unres_across=4     unres_within=2    ],
#  (Parse: then|WERE.NOT|sum|MER'S|dis.til|LA|tion.left)             [rank=None          meter=-++-+--+--   stress=+-++-+-+-+  score=13           is_bounded=True    w_peak=2           w_stress=4         s_unstress=2       unres_across=4     unres_within=1    ],
#  (Parse: then|WERE.NOT|sum|MER'S|dis.til|LA|tion|LEFT)             [rank=None          meter=-++-+--+-+   stress=+-++-+-+-+  score=10           is_bounded=True    w_peak=2           w_stress=3         s_unstress=2       unres_across=2     unres_within=1    ],
#  (Parse: then|WERE.NOT|sum|MER'S|dis.til|LA.TION|left)             [rank=None          meter=-++-+--++-   stress=+-++-+-+-+  score=13           is_bounded=True    w_peak=2           w_stress=4         s_unstress=3       unres_across=2     unres_within=2    ],
#  (Parse: then|WERE.NOT|sum|MER'S|dis.til.la|TION.LEFT)             [rank=None          meter=-++-+---++   stress=+-++-+-+-+  score=16           is_bounded=True    w_peak=3           w_stress=4         s_unstress=3       unres_across=4     unres_within=2    ],
#  (Parse: then|WERE.NOT|sum|MER'S|dis.til.la|TION|left)             [rank=None          meter=-++-+---+-   stress=+-++-+-+-+  score=15           is_bounded=True    w_peak=3           w_stress=5         s_unstress=3       unres_across=2     unres_within=2    ],
#  (Parse: then|WERE.NOT|sum|MER'S|dis.til.la.tion|LEFT)             [rank=None          meter=-++-+----+   stress=+-++-+-+-+  score=14           is_bounded=True    w_peak=3           w_stress=4         s_unstress=2       unres_across=2     unres_within=3    ],
#  (Parse: then|WERE.NOT|sum|MER'S.DIS|til.la.tion.left)             [rank=None          meter=-++-++----   stress=+-++-+-+-+  score=16           is_bounded=True    w_peak=2           w_stress=4         s_unstress=2       unres_across=6     unres_within=2    ],
#  (Parse: then|WERE.NOT|sum|MER'S.DIS|til|LA.TION.LEFT)             [rank=None          meter=-++-++-+++   stress=+-++-+-+-+  score=13           is_bounded=True    w_peak=1           w_stress=2         s_unstress=3       unres_across=6     unres_within=1    ],
#  (Parse: then|WERE.NOT|sum|MER'S.DIS|til|LA|tion.left)             [rank=None          meter=-++-++-+--   stress=+-++-+-+-+  score=12           is_bounded=True    w_peak=1           w_stress=3         s_unstress=2       unres_across=6    ],
#  (Parse: then|WERE.NOT|sum|MER'S.DIS|til|LA|tion|LEFT)             [rank=None          meter=-++-++-+-+   stress=+-++-+-+-+  score=9            is_bounded=True    w_peak=1           w_stress=2         s_unstress=2       unres_across=4    ],
#  (Parse: then|WERE.NOT|sum|MER'S.DIS|til|LA.TION|left)             [rank=None          meter=-++-++-++-   stress=+-++-+-+-+  score=12           is_bounded=True    w_peak=1           w_stress=3         s_unstress=3       unres_across=4     unres_within=1    ],
#  (Parse: then|WERE.NOT|sum|MER'S.DIS|til.la|TION.LEFT)             [rank=None          meter=-++-++--++   stress=+-++-+-+-+  score=15           is_bounded=True    w_peak=2           w_stress=3         s_unstress=3       unres_across=6     unres_within=1    ],
#  (Parse: then|WERE.NOT|sum|MER'S.DIS|til.la|TION|left)             [rank=None          meter=-++-++--+-   stress=+-++-+-+-+  score=14           is_bounded=True    w_peak=2           w_stress=4         s_unstress=3       unres_across=4     unres_within=1    ],
#  (Parse: then|WERE.NOT|sum|MER'S.DIS|til.la.tion|LEFT)             [rank=None          meter=-++-++---+   stress=+-++-+-+-+  score=13           is_bounded=True    w_peak=2           w_stress=3         s_unstress=2       unres_across=4     unres_within=2    ],
#  (Parse: then|WERE.NOT|sum|MER'S.DIS.TIL|la.tion.left)             [rank=None          meter=-++-+++---   stress=+-++-+-+-+  score=17           is_bounded=True    w_peak=2           w_stress=4         s_unstress=3       unres_across=6     unres_within=2    ],
#  (Parse: then|WERE.NOT|sum|MER'S.DIS.TIL|la|TION.LEFT)             [rank=None          meter=-++-+++-++   stress=+-++-+-+-+  score=16           is_bounded=True    w_peak=2           w_stress=3         s_unstress=4       unres_across=6     unres_within=1    ],
#  (Parse: then|WERE.NOT|sum|MER'S.DIS.TIL|la|TION|left)             [rank=None          meter=-++-+++-+-   stress=+-++-+-+-+  score=15           is_bounded=True    w_peak=2           w_stress=4         s_unstress=4       unres_across=4     unres_within=1    ],
#  (Parse: then|WERE.NOT|sum|MER'S.DIS.TIL|la.tion|LEFT)             [rank=None          meter=-++-+++--+   stress=+-++-+-+-+  score=14           is_bounded=True    w_peak=2           w_stress=3         s_unstress=3       unres_across=4     unres_within=2    ],
#  (Parse: then|WERE.NOT|sum|MER'S.DIS.TIL.LA|tion.left)             [rank=None          meter=-++-++++--   stress=+-++-+-+-+  score=15           is_bounded=True    w_peak=1           w_stress=3         s_unstress=3       unres_across=6     unres_within=2    ],
#  (Parse: then|WERE.NOT|sum|MER'S.DIS.TIL.LA|tion|LEFT)             [rank=None          meter=-++-++++-+   stress=+-++-+-+-+  score=12           is_bounded=True    w_peak=1           w_stress=2         s_unstress=3       unres_across=4     unres_within=2    ],
#  (Parse: then|WERE.NOT|sum|MER'S.DIS.TIL.LA.TION|left)             [rank=None          meter=-++-+++++-   stress=+-++-+-+-+  score=15           is_bounded=True    w_peak=1           w_stress=3         s_unstress=4       unres_across=4     unres_within=3    ],
#  (Parse: then|WERE.NOT|sum.mer's|DIS.TIL.LA.TION.LEFT)             [rank=None          meter=-++--+++++   stress=+-++-+-+-+  score=14           is_bounded=True    w_peak=1           w_stress=2         s_unstress=3       unres_across=4     unres_within=4    ],
#  (Parse: then|WERE.NOT|sum.mer's|DIS|til.la.tion.left)             [rank=None          meter=-++--+----   stress=+-++-+-+-+  score=14           is_bounded=True    w_peak=2           w_stress=4         s_unstress=1       unres_across=4     unres_within=3    ],
#  (Parse: then|WERE.NOT|sum.mer's|DIS|til|LA.TION.LEFT)             [rank=None          meter=-++--+-+++   stress=+-++-+-+-+  score=11           is_bounded=True    w_peak=1           w_stress=2         s_unstress=2       unres_across=4     unres_within=2    ],
#  (Parse: then|WERE.NOT|sum.mer's|DIS|til|LA|tion.left)             [rank=None          meter=-++--+-+--   stress=+-++-+-+-+  score=10           is_bounded=True    w_peak=1           w_stress=3         s_unstress=1       unres_across=4     unres_within=1    ],
#  (Parse: then|WERE.NOT|sum.mer's|DIS|til|LA|tion|LEFT)             [rank=None          meter=-++--+-+-+   stress=+-++-+-+-+  score=7            is_bounded=True    w_peak=1           w_stress=2         s_unstress=1       unres_across=2     unres_within=1    ],
#  (Parse: then|WERE.NOT|sum.mer's|DIS|til|LA.TION|left)             [rank=None          meter=-++--+-++-   stress=+-++-+-+-+  score=10           is_bounded=True    w_peak=1           w_stress=3         s_unstress=2       unres_across=2     unres_within=2    ],
#  (Parse: then|WERE.NOT|sum.mer's|DIS|til.la|TION.LEFT)             [rank=None          meter=-++--+--++   stress=+-++-+-+-+  score=13           is_bounded=True    w_peak=2           w_stress=3         s_unstress=2       unres_across=4     unres_within=2    ],
#  (Parse: then|WERE.NOT|sum.mer's|DIS|til.la|TION|left)             [rank=None          meter=-++--+--+-   stress=+-++-+-+-+  score=12           is_bounded=True    w_peak=2           w_stress=4         s_unstress=2       unres_across=2     unres_within=2    ],
#  (Parse: then|WERE.NOT|sum.mer's|DIS|til.la.tion|LEFT)             [rank=None          meter=-++--+---+   stress=+-++-+-+-+  score=11           is_bounded=True    w_peak=2           w_stress=3         s_unstress=1       unres_across=2     unres_within=3    ],
#  (Parse: then|WERE.NOT|sum.mer's|DIS.TIL|la.tion.left)             [rank=None          meter=-++--++---   stress=+-++-+-+-+  score=15           is_bounded=True    w_peak=2           w_stress=4         s_unstress=2       unres_across=4     unres_within=3    ],
#  (Parse: then|WERE.NOT|sum.mer's|DIS.TIL|la|TION.LEFT)             [rank=None          meter=-++--++-++   stress=+-++-+-+-+  score=14           is_bounded=True    w_peak=2           w_stress=3         s_unstress=3       unres_across=4     unres_within=2    ],
#  (Parse: then|WERE.NOT|sum.mer's|DIS.TIL|la|TION|left)             [rank=None          meter=-++--++-+-   stress=+-++-+-+-+  score=13           is_bounded=True    w_peak=2           w_stress=4         s_unstress=3       unres_across=2     unres_within=2    ],
#  (Parse: then|WERE.NOT|sum.mer's|DIS.TIL|la.tion|LEFT)             [rank=None          meter=-++--++--+   stress=+-++-+-+-+  score=12           is_bounded=True    w_peak=2           w_stress=3         s_unstress=2       unres_across=2     unres_within=3    ],
#  (Parse: then|WERE.NOT|sum.mer's|DIS.TIL.LA|tion.left)             [rank=None          meter=-++--+++--   stress=+-++-+-+-+  score=13           is_bounded=True    w_peak=1           w_stress=3         s_unstress=2       unres_across=4     unres_within=3    ],
#  (Parse: then|WERE.NOT|sum.mer's|DIS.TIL.LA|tion|LEFT)             [rank=None          meter=-++--+++-+   stress=+-++-+-+-+  score=10           is_bounded=True    w_peak=1           w_stress=2         s_unstress=2       unres_across=2     unres_within=3    ],
#  (Parse: then|WERE.NOT|sum.mer's|DIS.TIL.LA.TION|left)             [rank=None          meter=-++--++++-   stress=+-++-+-+-+  score=13           is_bounded=True    w_peak=1           w_stress=3         s_unstress=3       unres_across=2     unres_within=4    ],
#  (Parse: then|WERE.NOT|sum.mer's.dis|TIL.LA.TION.LEFT)             [rank=None          meter=-++---++++   stress=+-++-+-+-+  score=17           is_bounded=True    w_peak=2           w_stress=3         s_unstress=3       unres_across=6     unres_within=3    ],
#  (Parse: then|WERE.NOT|sum.mer's.dis|TIL|la.tion.left)             [rank=None          meter=-++---+---   stress=+-++-+-+-+  score=18           is_bounded=True    w_peak=3           w_stress=5         s_unstress=2       unres_across=6     unres_within=2    ],
#  (Parse: then|WERE.NOT|sum.mer's.dis|TIL|la|TION.LEFT)             [rank=None          meter=-++---+-++   stress=+-++-+-+-+  score=17           is_bounded=True    w_peak=3           w_stress=4         s_unstress=3       unres_across=6     unres_within=1    ],
#  (Parse: then|WERE.NOT|sum.mer's.dis|TIL|la|TION|left)             [rank=None          meter=-++---+-+-   stress=+-++-+-+-+  score=16           is_bounded=True    w_peak=3           w_stress=5         s_unstress=3       unres_across=4     unres_within=1    ],
#  (Parse: then|WERE.NOT|sum.mer's.dis|TIL|la.tion|LEFT)             [rank=None          meter=-++---+--+   stress=+-++-+-+-+  score=15           is_bounded=True    w_peak=3           w_stress=4         s_unstress=2       unres_across=4     unres_within=2    ],
#  (Parse: then|WERE.NOT|sum.mer's.dis|TIL.LA|tion.left)             [rank=None          meter=-++---++--   stress=+-++-+-+-+  score=16           is_bounded=True    w_peak=2           w_stress=4         s_unstress=2       unres_across=6     unres_within=2    ],
#  (Parse: then|WERE.NOT|sum.mer's.dis|TIL.LA|tion|LEFT)             [rank=None          meter=-++---++-+   stress=+-++-+-+-+  score=13           is_bounded=True    w_peak=2           w_stress=3         s_unstress=2       unres_across=4     unres_within=2    ],
# ...
#  (Parse: THEN.WERE.NOT|sum.mer's|DIS|til.la.tion|LEFT)             [rank=None          meter=+++--+---+   stress=+-++-+-+-+  score=11           is_bounded=True    w_peak=2           w_stress=2         s_unstress=1       unres_across=3     unres_within=3    ],
#  (Parse: THEN.WERE.NOT|sum.mer's|DIS.TIL|la.tion.left)             [rank=None          meter=+++--++---   stress=+-++-+-+-+  score=15           is_bounded=True    w_peak=2           w_stress=3         s_unstress=2       unres_across=5     unres_within=3    ],
#  (Parse: THEN.WERE.NOT|sum.mer's|DIS.TIL|la|TION.LEFT)             [rank=None          meter=+++--++-++   stress=+-++-+-+-+  score=14           is_bounded=True    w_peak=2           w_stress=2         s_unstress=3       unres_across=5     unres_within=2    ],
#  (Parse: THEN.WERE.NOT|sum.mer's|DIS.TIL|la|TION|left)             [rank=None          meter=+++--++-+-   stress=+-++-+-+-+  score=13           is_bounded=True    w_peak=2           w_stress=3         s_unstress=3       unres_across=3     unres_within=2    ],
#  (Parse: THEN.WERE.NOT|sum.mer's|DIS.TIL|la.tion|LEFT)             [rank=None          meter=+++--++--+   stress=+-++-+-+-+  score=12           is_bounded=True    w_peak=2           w_stress=2         s_unstress=2       unres_across=3     unres_within=3    ],
#  (Parse: THEN.WERE.NOT|sum.mer's|DIS.TIL.LA|tion.left)             [rank=None          meter=+++--+++--   stress=+-++-+-+-+  score=13           is_bounded=True    w_peak=1           w_stress=2         s_unstress=2       unres_across=5     unres_within=3    ],
#  (Parse: THEN.WERE.NOT|sum.mer's|DIS.TIL.LA|tion|LEFT)             [rank=None          meter=+++--+++-+   stress=+-++-+-+-+  score=10           is_bounded=True    w_peak=1           w_stress=1         s_unstress=2       unres_across=3     unres_within=3    ],
#  (Parse: THEN.WERE.NOT|sum.mer's|DIS.TIL.LA.TION|left)             [rank=None          meter=+++--++++-   stress=+-++-+-+-+  score=13           is_bounded=True    w_peak=1           w_stress=2         s_unstress=3       unres_across=3     unres_within=4    ],
#  (Parse: THEN.WERE.NOT|sum.mer's.dis|TIL.LA.TION.LEFT)             [rank=None          meter=+++---++++   stress=+-++-+-+-+  score=17           is_bounded=True    w_peak=2           w_stress=2         s_unstress=3       unres_across=7     unres_within=3    ],
#  (Parse: THEN.WERE.NOT|sum.mer's.dis|TIL|la.tion.left)             [rank=None          meter=+++---+---   stress=+-++-+-+-+  score=18           is_bounded=True    w_peak=3           w_stress=4         s_unstress=2       unres_across=7     unres_within=2    ],
#  (Parse: THEN.WERE.NOT|sum.mer's.dis|TIL|la|TION.LEFT)             [rank=None          meter=+++---+-++   stress=+-++-+-+-+  score=17           is_bounded=True    w_peak=3           w_stress=3         s_unstress=3       unres_across=7     unres_within=1    ],
#  (Parse: THEN.WERE.NOT|sum.mer's.dis|TIL|la|TION|left)             [rank=None          meter=+++---+-+-   stress=+-++-+-+-+  score=16           is_bounded=True    w_peak=3           w_stress=4         s_unstress=3       unres_across=5     unres_within=1    ],
#  (Parse: THEN.WERE.NOT|sum.mer's.dis|TIL|la.tion|LEFT)             [rank=None          meter=+++---+--+   stress=+-++-+-+-+  score=15           is_bounded=True    w_peak=3           w_stress=3         s_unstress=2       unres_across=5     unres_within=2    ],
#  (Parse: THEN.WERE.NOT|sum.mer's.dis|TIL.LA|tion.left)             [rank=None          meter=+++---++--   stress=+-++-+-+-+  score=16           is_bounded=True    w_peak=2           w_stress=3         s_unstress=2       unres_across=7     unres_within=2    ],
#  (Parse: THEN.WERE.NOT|sum.mer's.dis|TIL.LA|tion|LEFT)             [rank=None          meter=+++---++-+   stress=+-++-+-+-+  score=13           is_bounded=True    w_peak=2           w_stress=2         s_unstress=2       unres_across=5     unres_within=2    ],
#  (Parse: THEN.WERE.NOT|sum.mer's.dis|TIL.LA.TION|left)             [rank=None          meter=+++---+++-   stress=+-++-+-+-+  score=16           is_bounded=True    w_peak=2           w_stress=3         s_unstress=3       unres_across=5     unres_within=3    ],
#  (Parse: THEN.WERE.NOT|sum.mer's.dis.til|LA.TION.LEFT)             [rank=None          meter=+++----+++   stress=+-++-+-+-+  score=16           is_bounded=True    w_peak=2           w_stress=2         s_unstress=2       unres_across=7     unres_within=3    ],
#  (Parse: THEN.WERE.NOT|sum.mer's.dis.til|LA|tion.left)             [rank=None          meter=+++----+--   stress=+-++-+-+-+  score=15           is_bounded=True    w_peak=2           w_stress=3         s_unstress=1       unres_across=7     unres_within=2    ],
#  (Parse: THEN.WERE.NOT|sum.mer's.dis.til|LA|tion|LEFT)             [rank=None          meter=+++----+-+   stress=+-++-+-+-+  score=12           is_bounded=True    w_peak=2           w_stress=2         s_unstress=1       unres_across=5     unres_within=2    ],
#  (Parse: THEN.WERE.NOT|sum.mer's.dis.til|LA.TION|left)             [rank=None          meter=+++----++-   stress=+-++-+-+-+  score=15           is_bounded=True    w_peak=2           w_stress=3         s_unstress=2       unres_across=5     unres_within=3    ],
#  (Parse: THEN.WERE.NOT|sum.mer's.dis.til.la|TION.LEFT)             [rank=None          meter=+++-----++   stress=+-++-+-+-+  score=18           is_bounded=True    w_peak=3           w_stress=3         s_unstress=2       unres_across=7     unres_within=3    ],
#  (Parse: THEN.WERE.NOT|sum.mer's.dis.til.la|TION|left)             [rank=None          meter=+++-----+-   stress=+-++-+-+-+  score=17           is_bounded=True    w_peak=3           w_stress=4         s_unstress=2       unres_across=5     unres_within=3    ],
#  (Parse: THEN.WERE.NOT|sum.mer's.dis.til.la.tion|LEFT)             [rank=None          meter=+++------+   stress=+-++-+-+-+  score=16           is_bounded=True    w_peak=3           w_stress=3         s_unstress=1       unres_across=5     unres_within=4    ],
#  (Parse: THEN.WERE.NOT.SUM|mer's.dis.til.la.tion.left)             [rank=None          meter=++++------   stress=+-++-+-+-+  score=17           is_bounded=True    w_peak=2           w_stress=3         s_unstress=1       unres_across=8     unres_within=3    ],
#  (Parse: THEN.WERE.NOT.SUM|mer's|DIS.TIL.LA.TION.LEFT)             [rank=None          meter=++++-+++++   stress=+-++-+-+-+  score=12           is_bounded=True    s_unstress=3       unres_across=6     unres_within=3    ],
#  (Parse: THEN.WERE.NOT.SUM|mer's|DIS|til.la.tion.left)             [rank=None          meter=++++-+----   stress=+-++-+-+-+  score=12           is_bounded=True    w_peak=1           w_stress=2         s_unstress=1       unres_across=6     unres_within=2    ],
#  (Parse: THEN.WERE.NOT.SUM|mer's|DIS|til|LA.TION.LEFT)             [rank=None          meter=++++-+-+++   stress=+-++-+-+-+  score=9            is_bounded=True    s_unstress=2       unres_across=6     unres_within=1    ],
#  (Parse: THEN.WERE.NOT.SUM|mer's|DIS|til|LA|tion.left)             [rank=None          meter=++++-+-+--   stress=+-++-+-+-+  score=8            is_bounded=True    w_stress=1         s_unstress=1       unres_across=6    ],
#  (Parse: THEN.WERE.NOT.SUM|mer's|DIS|til|LA|tion|LEFT)             [rank=None          meter=++++-+-+-+   stress=+-++-+-+-+  score=5            is_bounded=True    s_unstress=1       unres_across=4    ],
#  (Parse: THEN.WERE.NOT.SUM|mer's|DIS|til|LA.TION|left)             [rank=None          meter=++++-+-++-   stress=+-++-+-+-+  score=8            is_bounded=True    w_stress=1         s_unstress=2       unres_across=4     unres_within=1    ],
#  (Parse: THEN.WERE.NOT.SUM|mer's|DIS|til.la|TION.LEFT)             [rank=None          meter=++++-+--++   stress=+-++-+-+-+  score=11           is_bounded=True    w_peak=1           w_stress=1         s_unstress=2       unres_across=6     unres_within=1    ],
#  (Parse: THEN.WERE.NOT.SUM|mer's|DIS|til.la|TION|left)             [rank=None          meter=++++-+--+-   stress=+-++-+-+-+  score=10           is_bounded=True    w_peak=1           w_stress=2         s_unstress=2       unres_across=4     unres_within=1    ],
#  (Parse: THEN.WERE.NOT.SUM|mer's|DIS|til.la.tion|LEFT)             [rank=None          meter=++++-+---+   stress=+-++-+-+-+  score=9            is_bounded=True    w_peak=1           w_stress=1         s_unstress=1       unres_across=4     unres_within=2    ],
#  (Parse: THEN.WERE.NOT.SUM|mer's|DIS.TIL|la.tion.left)             [rank=None          meter=++++-++---   stress=+-++-+-+-+  score=13           is_bounded=True    w_peak=1           w_stress=2         s_unstress=2       unres_across=6     unres_within=2    ],
#  (Parse: THEN.WERE.NOT.SUM|mer's|DIS.TIL|la|TION.LEFT)             [rank=None          meter=++++-++-++   stress=+-++-+-+-+  score=12           is_bounded=True    w_peak=1           w_stress=1         s_unstress=3       unres_across=6     unres_within=1    ],
#  (Parse: THEN.WERE.NOT.SUM|mer's|DIS.TIL|la|TION|left)             [rank=None          meter=++++-++-+-   stress=+-++-+-+-+  score=11           is_bounded=True    w_peak=1           w_stress=2         s_unstress=3       unres_across=4     unres_within=1    ],
#  (Parse: THEN.WERE.NOT.SUM|mer's|DIS.TIL|la.tion|LEFT)             [rank=None          meter=++++-++--+   stress=+-++-+-+-+  score=10           is_bounded=True    w_peak=1           w_stress=1         s_unstress=2       unres_across=4     unres_within=2    ],
#  (Parse: THEN.WERE.NOT.SUM|mer's|DIS.TIL.LA|tion.left)             [rank=None          meter=++++-+++--   stress=+-++-+-+-+  score=11           is_bounded=True    w_stress=1         s_unstress=2       unres_across=6     unres_within=2    ],
#  (Parse: THEN.WERE.NOT.SUM|mer's|DIS.TIL.LA|tion|LEFT)             [rank=None          meter=++++-+++-+   stress=+-++-+-+-+  score=8            is_bounded=True    s_unstress=2       unres_across=4     unres_within=2    ],
#  (Parse: THEN.WERE.NOT.SUM|mer's|DIS.TIL.LA.TION|left)             [rank=None          meter=++++-++++-   stress=+-++-+-+-+  score=11           is_bounded=True    w_stress=1         s_unstress=3       unres_across=4     unres_within=3    ],
#  (Parse: THEN.WERE.NOT.SUM|mer's.dis|TIL.LA.TION.LEFT)             [rank=None          meter=++++--++++   stress=+-++-+-+-+  score=15           is_bounded=True    w_peak=1           w_stress=1         s_unstress=3       unres_across=8     unres_within=2    ],
#  (Parse: THEN.WERE.NOT.SUM|mer's.dis|TIL|la.tion.left)             [rank=None          meter=++++--+---   stress=+-++-+-+-+  score=16           is_bounded=True    w_peak=2           w_stress=3         s_unstress=2       unres_across=8     unres_within=1    ],
#  (Parse: THEN.WERE.NOT.SUM|mer's.dis|TIL|la|TION.LEFT)             [rank=None          meter=++++--+-++   stress=+-++-+-+-+  score=15           is_bounded=True    w_peak=2           w_stress=2         s_unstress=3       unres_across=8    ],
#  (Parse: THEN.WERE.NOT.SUM|mer's.dis|TIL|la|TION|left)             [rank=None          meter=++++--+-+-   stress=+-++-+-+-+  score=14           is_bounded=True    w_peak=2           w_stress=3         s_unstress=3       unres_across=6    ],
#  (Parse: THEN.WERE.NOT.SUM|mer's.dis|TIL|la.tion|LEFT)             [rank=None          meter=++++--+--+   stress=+-++-+-+-+  score=13           is_bounded=True    w_peak=2           w_stress=2         s_unstress=2       unres_across=6     unres_within=1    ],
#  (Parse: THEN.WERE.NOT.SUM|mer's.dis|TIL.LA|tion.left)             [rank=None          meter=++++--++--   stress=+-++-+-+-+  score=14           is_bounded=True    w_peak=1           w_stress=2         s_unstress=2       unres_across=8     unres_within=1    ],
#  (Parse: THEN.WERE.NOT.SUM|mer's.dis|TIL.LA|tion|LEFT)             [rank=None          meter=++++--++-+   stress=+-++-+-+-+  score=11           is_bounded=True    w_peak=1           w_stress=1         s_unstress=2       unres_across=6     unres_within=1    ],
#  (Parse: THEN.WERE.NOT.SUM|mer's.dis|TIL.LA.TION|left)             [rank=None          meter=++++--+++-   stress=+-++-+-+-+  score=14           is_bounded=True    w_peak=1           w_stress=2         s_unstress=3       unres_across=6     unres_within=2    ],
#  (Parse: THEN.WERE.NOT.SUM|mer's.dis.til|LA.TION.LEFT)             [rank=None          meter=++++---+++   stress=+-++-+-+-+  score=14           is_bounded=True    w_peak=1           w_stress=1         s_unstress=2       unres_across=8     unres_within=2    ],
#  (Parse: THEN.WERE.NOT.SUM|mer's.dis.til|LA|tion.left)             [rank=None          meter=++++---+--   stress=+-++-+-+-+  score=13           is_bounded=True    w_peak=1           w_stress=2         s_unstress=1       unres_across=8     unres_within=1    ],
#  (Parse: THEN.WERE.NOT.SUM|mer's.dis.til|LA|tion|LEFT)             [rank=None          meter=++++---+-+   stress=+-++-+-+-+  score=10           is_bounded=True    w_peak=1           w_stress=1         s_unstress=1       unres_across=6     unres_within=1    ],
#  (Parse: THEN.WERE.NOT.SUM|mer's.dis.til|LA.TION|left)             [rank=None          meter=++++---++-   stress=+-++-+-+-+  score=13           is_bounded=True    w_peak=1           w_stress=2         s_unstress=2       unres_across=6     unres_within=2    ],
#  (Parse: THEN.WERE.NOT.SUM|mer's.dis.til.la|TION.LEFT)             [rank=None          meter=++++----++   stress=+-++-+-+-+  score=16           is_bounded=True    w_peak=2           w_stress=2         s_unstress=2       unres_across=8     unres_within=2    ],
#  (Parse: THEN.WERE.NOT.SUM|mer's.dis.til.la|TION|left)             [rank=None          meter=++++----+-   stress=+-++-+-+-+  score=15           is_bounded=True    w_peak=2           w_stress=3         s_unstress=2       unres_across=6     unres_within=2    ],
#  (Parse: THEN.WERE.NOT.SUM|mer's.dis.til.la.tion|LEFT)             [rank=None          meter=++++-----+   stress=+-++-+-+-+  score=14           is_bounded=True    w_peak=2           w_stress=2         s_unstress=1       unres_across=6     unres_within=3    ],
#  (Parse: THEN.WERE.NOT.SUM.MER'S|dis.til.la.tion.left)             [rank=None          meter=+++++-----   stress=+-++-+-+-+  score=17           is_bounded=True    w_peak=2           w_stress=3         s_unstress=2       unres_across=6     unres_within=4    ],
#  (Parse: THEN.WERE.NOT.SUM.MER'S|dis|TIL.LA.TION.LEFT)             [rank=None          meter=+++++-++++   stress=+-++-+-+-+  score=15           is_bounded=True    w_peak=1           w_stress=1         s_unstress=4       unres_across=6     unres_within=3    ],
#  (Parse: THEN.WERE.NOT.SUM.MER'S|dis|TIL|la.tion.left)             [rank=None          meter=+++++-+---   stress=+-++-+-+-+  score=16           is_bounded=True    w_peak=2           w_stress=3         s_unstress=3       unres_across=6     unres_within=2    ],
#  (Parse: THEN.WERE.NOT.SUM.MER'S|dis|TIL|la|TION.LEFT)             [rank=None          meter=+++++-+-++   stress=+-++-+-+-+  score=15           is_bounded=True    w_peak=2           w_stress=2         s_unstress=4       unres_across=6     unres_within=1    ],
#  (Parse: THEN.WERE.NOT.SUM.MER'S|dis|TIL|la|TION|left)             [rank=None          meter=+++++-+-+-   stress=+-++-+-+-+  score=14           is_bounded=True    w_peak=2           w_stress=3         s_unstress=4       unres_across=4     unres_within=1    ],
#  (Parse: THEN.WERE.NOT.SUM.MER'S|dis|TIL|la.tion|LEFT)             [rank=None          meter=+++++-+--+   stress=+-++-+-+-+  score=13           is_bounded=True    w_peak=2           w_stress=2         s_unstress=3       unres_across=4     unres_within=2    ],
#  (Parse: THEN.WERE.NOT.SUM.MER'S|dis|TIL.LA|tion.left)             [rank=None          meter=+++++-++--   stress=+-++-+-+-+  score=14           is_bounded=True    w_peak=1           w_stress=2         s_unstress=3       unres_across=6     unres_within=2    ],
#  ...]

# %%
l.scansions
# Out:
# [(Parse: leese|BUT|their|SHOW|their|SUBS|tance|STILL|lives|SWEET)  [rank=1             meter=-+-+-+-+-+   stress=++++++-+++  score=4            is_bounded=False   w_stress=4        ],
#  (Parse: LEESE|but|THEIR|show|THEIR.SUBS|tance|STILL|lives|SWEET)  [rank=2             meter=+-+-++-+-+   stress=++++++-+++  score=5            is_bounded=False   w_stress=3         unres_across=2    ],
#  (Parse: LEESE|but|THEIR.SHOW|their|SUBS|tance|STILL|lives|SWEET)  [rank=3             meter=+-++-+-+-+   stress=++++++-+++  score=5            is_bounded=False   w_stress=3         unres_across=2    ],
#  (Parse: LEESE.BUT|their|SHOW|their|SUBS|tance|STILL|lives|SWEET)  [rank=4             meter=++-+-+-+-+   stress=++++++-+++  score=5            is_bounded=False   w_stress=3         unres_across=2    ],
#  (Parse: leese|BUT|their|SHOW|their|SUBS|tance|STILL.LIVES|sweet)  [rank=5             meter=-+-+-+-++-   stress=++++++-+++  score=6            is_bounded=False   w_stress=4         unres_across=2    ],
#  (Parse: LEESE|but|THEIR|show|THEIR|subs.tance|STILL|lives|SWEET)  [rank=6             meter=+-+-+--+-+   stress=++++++-+++  score=6            is_bounded=False   w_peak=1           w_stress=4         unres_within=1    ],
#  (Parse: LEESE|but|THEIR|show.their|SUBS|tance|STILL|lives|SWEET)  [rank=7             meter=+-+--+-+-+   stress=++++++-+++  score=6            is_bounded=False   w_stress=4         unres_across=2    ],
#  (Parse: LEESE|but.their|SHOW|their|SUBS|tance|STILL|lives|SWEET)  [rank=8             meter=+--+-+-+-+   stress=++++++-+++  score=6            is_bounded=False   w_stress=4         unres_across=2    ],
#  (Parse: leese|BUT|their|SHOW|their|SUBS|tance|STILL|lives.sweet)  [rank=9             meter=-+-+-+-+--   stress=++++++-+++  score=7            is_bounded=False   w_stress=5         unres_across=2    ],
#  (Parse: leese|BUT|their|SHOW|their|SUBS|tance.still|LIVES|sweet)  [rank=10            meter=-+-+-+--+-   stress=++++++-+++  score=7            is_bounded=False   w_stress=5         unres_across=2    ],
#  (Parse: leese|BUT|their|SHOW|their|SUBS.TANCE|still|LIVES|sweet)  [rank=11            meter=-+-+-++-+-   stress=++++++-+++  score=7            is_bounded=False   w_stress=5         s_unstress=1       unres_within=1    ],
#  (Parse: leese|BUT.THEIR|show|THEIR.SUBS|tance|STILL|lives|SWEET)  [rank=12            meter=-++-++-+-+   stress=++++++-+++  score=7            is_bounded=False   w_stress=3         unres_across=4    ],
#  (Parse: LEESE|but|THEIR|show|THEIR|subs|TANCE|still|LIVES|sweet)  [rank=13            meter=+-+-+-+-+-   stress=++++++-+++  score=7            is_bounded=False   w_peak=1           w_stress=5         s_unstress=1      ],
#  (Parse: LEESE|but|THEIR|show|THEIR.SUBS|tance|STILL.LIVES|sweet)  [rank=14            meter=+-+-++-++-   stress=++++++-+++  score=7            is_bounded=False   w_stress=3         unres_across=4    ],
#  (Parse: LEESE|but|THEIR.SHOW|their|SUBS|tance|STILL.LIVES|sweet)  [rank=15            meter=+-++-+-++-   stress=++++++-+++  score=7            is_bounded=False   w_stress=3         unres_across=4    ],
#  (Parse: LEESE.BUT|their|SHOW|their|SUBS|tance|STILL.LIVES|sweet)  [rank=16            meter=++-+-+-++-   stress=++++++-+++  score=7            is_bounded=False   w_stress=3         unres_across=4    ],
#  (Parse: leese|BUT|their|SHOW|their|SUBS|tance.still|LIVES.SWEET)  [rank=17            meter=-+-+-+--++   stress=++++++-+++  score=8            is_bounded=False   w_stress=4         unres_across=4    ],
#  (Parse: leese|BUT|their|SHOW|their|SUBS.TANCE|still|LIVES.SWEET)  [rank=18            meter=-+-+-++-++   stress=++++++-+++  score=8            is_bounded=False   w_stress=4         s_unstress=1       unres_across=2     unres_within=1    ],
#  (Parse: leese|BUT|their|SHOW.THEIR|subs.tance|STILL|lives|SWEET)  [rank=19            meter=-+-++--+-+   stress=++++++-+++  score=8            is_bounded=False   w_peak=1           w_stress=4         unres_across=2     unres_within=1    ],
#  (Parse: leese|BUT|their.show|THEIR.SUBS|tance|STILL|lives|SWEET)  [rank=20            meter=-+--++-+-+   stress=++++++-+++  score=8            is_bounded=False   w_stress=4         unres_across=4    ],
#  (Parse: leese|BUT.THEIR|show|THEIR|subs.tance|STILL|lives|SWEET)  [rank=21            meter=-++-+--+-+   stress=++++++-+++  score=8            is_bounded=False   w_peak=1           w_stress=4         unres_across=2     unres_within=1    ],
#  (Parse: leese|BUT.THEIR|show.their|SUBS|tance|STILL|lives|SWEET)  [rank=22            meter=-++--+-+-+   stress=++++++-+++  score=8            is_bounded=False   w_stress=4         unres_across=4    ],
#  (Parse: leese.but|THEIR|show|THEIR.SUBS|tance|STILL|lives|SWEET)  [rank=23            meter=--+-++-+-+   stress=++++++-+++  score=8            is_bounded=False   w_stress=4         unres_across=4    ],
#  (Parse: leese.but|THEIR.SHOW|their|SUBS|tance|STILL|lives|SWEET)  [rank=24            meter=--++-+-+-+   stress=++++++-+++  score=8            is_bounded=False   w_stress=4         unres_across=4    ],
#  (Parse: LEESE|but|THEIR|show|THEIR|subs|TANCE|still|LIVES.SWEET)  [rank=25            meter=+-+-+-+-++   stress=++++++-+++  score=8            is_bounded=False   w_peak=1           w_stress=4         s_unstress=1       unres_across=2    ],
#  (Parse: LEESE|but|THEIR|show|THEIR|subs|TANCE.STILL|lives|SWEET)  [rank=26            meter=+-+-+-++-+   stress=++++++-+++  score=8            is_bounded=False   w_peak=1           w_stress=4         s_unstress=1       unres_across=2    ],
#  (Parse: LEESE|but|THEIR|show|THEIR|subs.tance|STILL.LIVES|sweet)  [rank=27            meter=+-+-+--++-   stress=++++++-+++  score=8            is_bounded=False   w_peak=1           w_stress=4         unres_across=2     unres_within=1    ],
#  (Parse: LEESE|but|THEIR|show|THEIR.SUBS|tance|STILL|lives.sweet)  [rank=28            meter=+-+-++-+--   stress=++++++-+++  score=8            is_bounded=False   w_stress=4         unres_across=4    ],
#  (Parse: LEESE|but|THEIR|show|THEIR.SUBS|tance.still|LIVES|sweet)  [rank=29            meter=+-+-++--+-   stress=++++++-+++  score=8            is_bounded=False   w_stress=4         unres_across=4    ],
#  (Parse: LEESE|but|THEIR|show.their|SUBS|tance|STILL.LIVES|sweet)  [rank=30            meter=+-+--+-++-   stress=++++++-+++  score=8            is_bounded=False   w_stress=4         unres_across=4    ],
#  (Parse: LEESE|but|THEIR.SHOW|their|SUBS|tance|STILL|lives.sweet)  [rank=31            meter=+-++-+-+--   stress=++++++-+++  score=8            is_bounded=False   w_stress=4         unres_across=4    ],
#  (Parse: LEESE|but|THEIR.SHOW|their|SUBS|tance.still|LIVES|sweet)  [rank=32            meter=+-++-+--+-   stress=++++++-+++  score=8            is_bounded=False   w_stress=4         unres_across=4    ],
#  (Parse: LEESE|but|THEIR.SHOW|their|SUBS.TANCE|still|LIVES|sweet)  [rank=33            meter=+-++-++-+-   stress=++++++-+++  score=8            is_bounded=False   w_stress=4         s_unstress=1       unres_across=2     unres_within=1    ],
#  (Parse: LEESE|but.their|SHOW|their|SUBS|tance|STILL.LIVES|sweet)  [rank=34            meter=+--+-+-++-   stress=++++++-+++  score=8            is_bounded=False   w_stress=4         unres_across=4    ],
#  (Parse: LEESE.BUT|their|SHOW|their|SUBS|tance|STILL|lives.sweet)  [rank=35            meter=++-+-+-+--   stress=++++++-+++  score=8            is_bounded=False   w_stress=4         unres_across=4    ],
#  (Parse: LEESE.BUT|their|SHOW|their|SUBS|tance.still|LIVES|sweet)  [rank=36            meter=++-+-+--+-   stress=++++++-+++  score=8            is_bounded=False   w_stress=4         unres_across=4    ],
#  (Parse: LEESE.BUT|their|SHOW|their|SUBS.TANCE|still|LIVES|sweet)  [rank=37            meter=++-+-++-+-   stress=++++++-+++  score=8            is_bounded=False   w_stress=4         s_unstress=1       unres_across=2     unres_within=1    ],
#  (Parse: leese|BUT|their|SHOW|their|SUBS.TANCE|still.lives|SWEET)  [rank=38            meter=-+-+-++--+   stress=++++++-+++  score=9            is_bounded=False   w_stress=5         s_unstress=1       unres_across=2     unres_within=1    ],
#  (Parse: leese|BUT|their|SHOW.THEIR|subs|TANCE|still|LIVES|sweet)  [rank=39            meter=-+-++-+-+-   stress=++++++-+++  score=9            is_bounded=False   w_peak=1           w_stress=5         s_unstress=1       unres_across=2    ],
#  (Parse: leese|BUT|their.show|THEIR|subs.tance|STILL|lives|SWEET)  [rank=40            meter=-+--+--+-+   stress=++++++-+++  score=9            is_bounded=False   w_peak=1           w_stress=5         unres_across=2     unres_within=1    ],
#  (Parse: leese|BUT.THEIR|show|THEIR|subs|TANCE|still|LIVES|sweet)  [rank=41            meter=-++-+-+-+-   stress=++++++-+++  score=9            is_bounded=False   w_peak=1           w_stress=5         s_unstress=1       unres_across=2    ],
#  (Parse: leese|BUT.THEIR|show|THEIR.SUBS|tance|STILL.LIVES|sweet)  [rank=42            meter=-++-++-++-   stress=++++++-+++  score=9            is_bounded=False   w_stress=3         unres_across=6    ],
#  (Parse: leese.but|THEIR|show|THEIR|subs.tance|STILL|lives|SWEET)  [rank=43            meter=--+-+--+-+   stress=++++++-+++  score=9            is_bounded=False   w_peak=1           w_stress=5         unres_across=2     unres_within=1    ],
#  (Parse: leese.but|THEIR|show.their|SUBS|tance|STILL|lives|SWEET)  [rank=44            meter=--+--+-+-+   stress=++++++-+++  score=9            is_bounded=False   w_stress=5         unres_across=4    ],
#  (Parse: LEESE|but|THEIR|show|THEIR|subs|TANCE|still.lives|SWEET)  [rank=45            meter=+-+-+-+--+   stress=++++++-+++  score=9            is_bounded=False   w_peak=1           w_stress=5         s_unstress=1       unres_across=2    ],
#  (Parse: LEESE|but|THEIR|show|THEIR|subs.tance|STILL|lives.sweet)  [rank=46            meter=+-+-+--+--   stress=++++++-+++  score=9            is_bounded=False   w_peak=1           w_stress=5         unres_across=2     unres_within=1    ],
#  (Parse: LEESE|but|THEIR|show|THEIR.SUBS|tance.still|LIVES.SWEET)  [rank=47            meter=+-+-++--++   stress=++++++-+++  score=9            is_bounded=False   w_stress=3         unres_across=6    ],
#  (Parse: LEESE|but|THEIR|show.their|SUBS|tance|STILL|lives.sweet)  [rank=48            meter=+-+--+-+--   stress=++++++-+++  score=9            is_bounded=False   w_stress=5         unres_across=4    ],
#  (Parse: LEESE|but|THEIR|show.their|SUBS|tance.still|LIVES|sweet)  [rank=49            meter=+-+--+--+-   stress=++++++-+++  score=9            is_bounded=False   w_stress=5         unres_across=4    ],
#  (Parse: LEESE|but|THEIR|show.their|SUBS.TANCE|still|LIVES|sweet)  [rank=50            meter=+-+--++-+-   stress=++++++-+++  score=9            is_bounded=False   w_stress=5         s_unstress=1       unres_across=2     unres_within=1    ],
#  (Parse: LEESE|but|THEIR.SHOW|their|SUBS|tance.still|LIVES.SWEET)  [rank=51            meter=+-++-+--++   stress=++++++-+++  score=9            is_bounded=False   w_stress=3         unres_across=6    ],
#  (Parse: LEESE|but|THEIR.SHOW|their|SUBS.TANCE|still|LIVES.SWEET)  [rank=52            meter=+-++-++-++   stress=++++++-+++  score=9            is_bounded=False   w_stress=3         s_unstress=1       unres_across=4     unres_within=1    ],
#  (Parse: LEESE|but.their|SHOW|their|SUBS|tance|STILL|lives.sweet)  [rank=53            meter=+--+-+-+--   stress=++++++-+++  score=9            is_bounded=False   w_stress=5         unres_across=4    ],
#  (Parse: LEESE|but.their|SHOW|their|SUBS|tance.still|LIVES|sweet)  [rank=54            meter=+--+-+--+-   stress=++++++-+++  score=9            is_bounded=False   w_stress=5         unres_across=4    ],
#  (Parse: LEESE|but.their|SHOW|their|SUBS.TANCE|still|LIVES|sweet)  [rank=55            meter=+--+-++-+-   stress=++++++-+++  score=9            is_bounded=False   w_stress=5         s_unstress=1       unres_across=2     unres_within=1    ],
#  (Parse: LEESE.BUT|their|SHOW|their|SUBS|tance.still|LIVES.SWEET)  [rank=56            meter=++-+-+--++   stress=++++++-+++  score=9            is_bounded=False   w_stress=3         unres_across=6    ],
#  (Parse: LEESE.BUT|their|SHOW|their|SUBS.TANCE|still|LIVES.SWEET)  [rank=57            meter=++-+-++-++   stress=++++++-+++  score=9            is_bounded=False   w_stress=3         s_unstress=1       unres_across=4     unres_within=1    ],
#  (Parse: LEESE.BUT|their|SHOW.THEIR|subs.tance|STILL|lives|SWEET)  [rank=58            meter=++-++--+-+   stress=++++++-+++  score=9            is_bounded=False   w_peak=1           w_stress=3         unres_across=4     unres_within=1    ],
#  (Parse: LEESE.BUT|their.show|THEIR.SUBS|tance|STILL|lives|SWEET)  [rank=59            meter=++--++-+-+   stress=++++++-+++  score=9            is_bounded=False   w_stress=3         unres_across=6    ],
#  (Parse: leese|BUT|their|SHOW|their.subs|TANCE|still|LIVES|sweet)  [rank=60            meter=-+-+--+-+-   stress=++++++-+++  score=10           is_bounded=False   w_peak=1           w_stress=6         s_unstress=1       unres_across=2    ],
#  (Parse: leese|BUT|their|SHOW.THEIR|subs|TANCE|still|LIVES.SWEET)  [rank=61            meter=-+-++-+-++   stress=++++++-+++  score=10           is_bounded=False   w_peak=1           w_stress=4         s_unstress=1       unres_across=4    ],
#  (Parse: leese|BUT|their|SHOW.THEIR|subs|TANCE.STILL|lives|SWEET)  [rank=62            meter=-+-++-++-+   stress=++++++-+++  score=10           is_bounded=False   w_peak=1           w_stress=4         s_unstress=1       unres_across=4    ],
#  (Parse: leese|BUT|their|SHOW.THEIR|subs.tance|STILL.LIVES|sweet)  [rank=63            meter=-+-++--++-   stress=++++++-+++  score=10           is_bounded=False   w_peak=1           w_stress=4         unres_across=4     unres_within=1    ],
#  (Parse: leese|BUT|their.show|THEIR|subs|TANCE|still|LIVES|sweet)  [rank=64            meter=-+--+-+-+-   stress=++++++-+++  score=10           is_bounded=False   w_peak=1           w_stress=6         s_unstress=1       unres_across=2    ],
#  (Parse: leese|BUT|their.show|THEIR.SUBS|tance|STILL.LIVES|sweet)  [rank=65            meter=-+--++-++-   stress=++++++-+++  score=10           is_bounded=False   w_stress=4         unres_across=6    ],
#  (Parse: leese|BUT.THEIR|show|THEIR|subs|TANCE|still|LIVES.SWEET)  [rank=66            meter=-++-+-+-++   stress=++++++-+++  score=10           is_bounded=False   w_peak=1           w_stress=4         s_unstress=1       unres_across=4    ],
#  (Parse: leese|BUT.THEIR|show|THEIR|subs|TANCE.STILL|lives|SWEET)  [rank=67            meter=-++-+-++-+   stress=++++++-+++  score=10           is_bounded=False   w_peak=1           w_stress=4         s_unstress=1       unres_across=4    ],
#  (Parse: leese|BUT.THEIR|show|THEIR|subs.tance|STILL.LIVES|sweet)  [rank=68            meter=-++-+--++-   stress=++++++-+++  score=10           is_bounded=False   w_peak=1           w_stress=4         unres_across=4     unres_within=1    ],
#  (Parse: leese|BUT.THEIR|show|THEIR.SUBS|tance|STILL|lives.sweet)  [rank=69            meter=-++-++-+--   stress=++++++-+++  score=10           is_bounded=False   w_stress=4         unres_across=6    ],
#  (Parse: leese|BUT.THEIR|show|THEIR.SUBS|tance.still|LIVES|sweet)  [rank=70            meter=-++-++--+-   stress=++++++-+++  score=10           is_bounded=False   w_stress=4         unres_across=6    ],
#  (Parse: leese|BUT.THEIR|show.their|SUBS|tance|STILL.LIVES|sweet)  [rank=71            meter=-++--+-++-   stress=++++++-+++  score=10           is_bounded=False   w_stress=4         unres_across=6    ],
#  (Parse: leese.but|THEIR|show|THEIR|subs|TANCE|still|LIVES|sweet)  [rank=72            meter=--+-+-+-+-   stress=++++++-+++  score=10           is_bounded=False   w_peak=1           w_stress=6         s_unstress=1       unres_across=2    ],
#  (Parse: leese.but|THEIR|show|THEIR.SUBS|tance|STILL.LIVES|sweet)  [rank=73            meter=--+-++-++-   stress=++++++-+++  score=10           is_bounded=False   w_stress=4         unres_across=6    ],
#  (Parse: leese.but|THEIR.SHOW|their|SUBS|tance|STILL.LIVES|sweet)  [rank=74            meter=--++-+-++-   stress=++++++-+++  score=10           is_bounded=False   w_stress=4         unres_across=6    ],
#  (Parse: LEESE|but|THEIR|show.their|SUBS|tance.still|LIVES.SWEET)  [rank=75            meter=+-+--+--++   stress=++++++-+++  score=10           is_bounded=False   w_stress=4         unres_across=6    ],
#  (Parse: LEESE|but|THEIR|show.their|SUBS.TANCE|still|LIVES.SWEET)  [rank=76            meter=+-+--++-++   stress=++++++-+++  score=10           is_bounded=False   w_stress=4         s_unstress=1       unres_across=4     unres_within=1    ],
#  (Parse: LEESE|but|THEIR.SHOW|their|SUBS.TANCE|still.lives|SWEET)  [rank=77            meter=+-++-++--+   stress=++++++-+++  score=10           is_bounded=False   w_stress=4         s_unstress=1       unres_across=4     unres_within=1    ],
#  (Parse: LEESE|but.their|SHOW|their|SUBS|tance.still|LIVES.SWEET)  [rank=78            meter=+--+-+--++   stress=++++++-+++  score=10           is_bounded=False   w_stress=4         unres_across=6    ],
#  (Parse: LEESE|but.their|SHOW|their|SUBS.TANCE|still|LIVES.SWEET)  [rank=79            meter=+--+-++-++   stress=++++++-+++  score=10           is_bounded=False   w_stress=4         s_unstress=1       unres_across=4     unres_within=1    ],
#  (Parse: LEESE|but.their|SHOW.THEIR|subs.tance|STILL|lives|SWEET)  [rank=80            meter=+--++--+-+   stress=++++++-+++  score=10           is_bounded=False   w_peak=1           w_stress=4         unres_across=4     unres_within=1    ],
#  (Parse: LEESE.BUT|their|SHOW|their|SUBS.TANCE|still.lives|SWEET)  [rank=81            meter=++-+-++--+   stress=++++++-+++  score=10           is_bounded=False   w_stress=4         s_unstress=1       unres_across=4     unres_within=1    ],
#  (Parse: LEESE.BUT|their|SHOW.THEIR|subs|TANCE|still|LIVES|sweet)  [rank=82            meter=++-++-+-+-   stress=++++++-+++  score=10           is_bounded=False   w_peak=1           w_stress=4         s_unstress=1       unres_across=4    ],
#  (Parse: LEESE.BUT|their.show|THEIR|subs.tance|STILL|lives|SWEET)  [rank=83            meter=++--+--+-+   stress=++++++-+++  score=10           is_bounded=False   w_peak=1           w_stress=4         unres_across=4     unres_within=1    ],
#  (Parse: leese|BUT|their|SHOW|their.subs|TANCE|still|LIVES.SWEET)  [rank=84            meter=-+-+--+-++   stress=++++++-+++  score=11           is_bounded=False   w_peak=1           w_stress=5         s_unstress=1       unres_across=4    ],
#  (Parse: leese|BUT|their|SHOW|their.subs|TANCE.STILL|lives|SWEET)  [rank=85            meter=-+-+--++-+   stress=++++++-+++  score=11           is_bounded=False   w_peak=1           w_stress=5         s_unstress=1       unres_across=4    ],
#  (Parse: leese|BUT|their|SHOW.THEIR|subs|TANCE|still.lives|SWEET)  [rank=86            meter=-+-++-+--+   stress=++++++-+++  score=11           is_bounded=False   w_peak=1           w_stress=5         s_unstress=1       unres_across=4    ],
#  (Parse: leese|BUT|their|SHOW.THEIR|subs.tance|STILL|lives.sweet)  [rank=87            meter=-+-++--+--   stress=++++++-+++  score=11           is_bounded=False   w_peak=1           w_stress=5         unres_across=4     unres_within=1    ],
#  (Parse: leese|BUT|their.show|THEIR|subs|TANCE|still|LIVES.SWEET)  [rank=88            meter=-+--+-+-++   stress=++++++-+++  score=11           is_bounded=False   w_peak=1           w_stress=5         s_unstress=1       unres_across=4    ],
#  (Parse: leese|BUT|their.show|THEIR|subs|TANCE.STILL|lives|SWEET)  [rank=89            meter=-+--+-++-+   stress=++++++-+++  score=11           is_bounded=False   w_peak=1           w_stress=5         s_unstress=1       unres_across=4    ],
#  (Parse: leese|BUT|their.show|THEIR|subs.tance|STILL.LIVES|sweet)  [rank=90            meter=-+--+--++-   stress=++++++-+++  score=11           is_bounded=False   w_peak=1           w_stress=5         unres_across=4     unres_within=1    ],
#  (Parse: leese|BUT|their.show|THEIR.SUBS|tance|STILL|lives.sweet)  [rank=91            meter=-+--++-+--   stress=++++++-+++  score=11           is_bounded=False   w_stress=5         unres_across=6    ],
#  (Parse: leese|BUT|their.show|THEIR.SUBS|tance.still|LIVES|sweet)  [rank=92            meter=-+--++--+-   stress=++++++-+++  score=11           is_bounded=False   w_stress=5         unres_across=6    ],
#  (Parse: leese|BUT.THEIR|show|THEIR|subs|TANCE|still.lives|SWEET)  [rank=93            meter=-++-+-+--+   stress=++++++-+++  score=11           is_bounded=False   w_peak=1           w_stress=5         s_unstress=1       unres_across=4    ],
#  (Parse: leese|BUT.THEIR|show|THEIR|subs.tance|STILL|lives.sweet)  [rank=94            meter=-++-+--+--   stress=++++++-+++  score=11           is_bounded=False   w_peak=1           w_stress=5         unres_across=4     unres_within=1    ],
#  (Parse: leese|BUT.THEIR|show|THEIR.SUBS|tance.still|LIVES.SWEET)  [rank=95            meter=-++-++--++   stress=++++++-+++  score=11           is_bounded=False   w_stress=3         unres_across=8    ],
#  (Parse: leese|BUT.THEIR|show.their|SUBS|tance|STILL|lives.sweet)  [rank=96            meter=-++--+-+--   stress=++++++-+++  score=11           is_bounded=False   w_stress=5         unres_across=6    ],
#  (Parse: leese|BUT.THEIR|show.their|SUBS|tance.still|LIVES|sweet)  [rank=97            meter=-++--+--+-   stress=++++++-+++  score=11           is_bounded=False   w_stress=5         unres_across=6    ],
#  (Parse: leese|BUT.THEIR|show.their|SUBS.TANCE|still|LIVES|sweet)  [rank=98            meter=-++--++-+-   stress=++++++-+++  score=11           is_bounded=False   w_stress=5         s_unstress=1       unres_across=4     unres_within=1    ],
#  (Parse: leese.but|THEIR|show|THEIR|subs|TANCE|still|LIVES.SWEET)  [rank=99            meter=--+-+-+-++   stress=++++++-+++  score=11           is_bounded=False   w_peak=1           w_stress=5         s_unstress=1       unres_across=4    ],
#  (Parse: leese.but|THEIR|show|THEIR|subs|TANCE.STILL|lives|SWEET)  [rank=100           meter=--+-+-++-+   stress=++++++-+++  score=11           is_bounded=False   w_peak=1           w_stress=5         s_unstress=1       unres_across=4    ],
#  (Parse: leese.but|THEIR|show|THEIR|subs.tance|STILL.LIVES|sweet)  [rank=101           meter=--+-+--++-   stress=++++++-+++  score=11           is_bounded=False   w_peak=1           w_stress=5         unres_across=4     unres_within=1    ],
#  (Parse: leese.but|THEIR|show|THEIR.SUBS|tance|STILL|lives.sweet)  [rank=102           meter=--+-++-+--   stress=++++++-+++  score=11           is_bounded=False   w_stress=5         unres_across=6    ],
#  (Parse: leese.but|THEIR|show|THEIR.SUBS|tance.still|LIVES|sweet)  [rank=103           meter=--+-++--+-   stress=++++++-+++  score=11           is_bounded=False   w_stress=5         unres_across=6    ],
#  (Parse: leese.but|THEIR|show.their|SUBS|tance|STILL.LIVES|sweet)  [rank=104           meter=--+--+-++-   stress=++++++-+++  score=11           is_bounded=False   w_stress=5         unres_across=6    ],
#  (Parse: leese.but|THEIR.SHOW|their|SUBS|tance|STILL|lives.sweet)  [rank=105           meter=--++-+-+--   stress=++++++-+++  score=11           is_bounded=False   w_stress=5         unres_across=6    ],
#  (Parse: leese.but|THEIR.SHOW|their|SUBS|tance.still|LIVES|sweet)  [rank=106           meter=--++-+--+-   stress=++++++-+++  score=11           is_bounded=False   w_stress=5         unres_across=6    ],
#  (Parse: leese.but|THEIR.SHOW|their|SUBS.TANCE|still|LIVES|sweet)  [rank=107           meter=--++-++-+-   stress=++++++-+++  score=11           is_bounded=False   w_stress=5         s_unstress=1       unres_across=4     unres_within=1    ],
#  (Parse: LEESE|but|THEIR|show|THEIR|subs|TANCE.STILL|lives.sweet)  [rank=108           meter=+-+-+-++--   stress=++++++-+++  score=11           is_bounded=False   w_peak=1           w_stress=5         s_unstress=1       unres_across=4    ],
#  (Parse: LEESE|but|THEIR|show.their|SUBS.TANCE|still.lives|SWEET)  [rank=109           meter=+-+--++--+   stress=++++++-+++  score=11           is_bounded=False   w_stress=5         s_unstress=1       unres_across=4     unres_within=1    ],
#  (Parse: LEESE|but|THEIR.SHOW|their.subs|TANCE|still|LIVES|sweet)  [rank=110           meter=+-++--+-+-   stress=++++++-+++  score=11           is_bounded=False   w_peak=1           w_stress=5         s_unstress=1       unres_across=4    ],
#  (Parse: LEESE|but.their|SHOW|their|SUBS.TANCE|still.lives|SWEET)  [rank=111           meter=+--+-++--+   stress=++++++-+++  score=11           is_bounded=False   w_stress=5         s_unstress=1       unres_across=4     unres_within=1    ],
#  (Parse: LEESE|but.their|SHOW.THEIR|subs|TANCE|still|LIVES|sweet)  [rank=112           meter=+--++-+-+-   stress=++++++-+++  score=11           is_bounded=False   w_peak=1           w_stress=5         s_unstress=1       unres_across=4    ],
#  (Parse: LEESE.BUT|their|SHOW|their.subs|TANCE|still|LIVES|sweet)  [rank=113           meter=++-+--+-+-   stress=++++++-+++  score=11           is_bounded=False   w_peak=1           w_stress=5         s_unstress=1       unres_across=4    ],
#  (Parse: LEESE.BUT|their|SHOW.THEIR|subs|TANCE|still|LIVES.SWEET)  [rank=114           meter=++-++-+-++   stress=++++++-+++  score=11           is_bounded=False   w_peak=1           w_stress=3         s_unstress=1       unres_across=6    ],
#  (Parse: LEESE.BUT|their|SHOW.THEIR|subs|TANCE.STILL|lives|SWEET)  [rank=115           meter=++-++-++-+   stress=++++++-+++  score=11           is_bounded=False   w_peak=1           w_stress=3         s_unstress=1       unres_across=6    ],
#  (Parse: LEESE.BUT|their|SHOW.THEIR|subs.tance|STILL.LIVES|sweet)  [rank=116           meter=++-++--++-   stress=++++++-+++  score=11           is_bounded=False   w_peak=1           w_stress=3         unres_across=6     unres_within=1    ],
#  (Parse: LEESE.BUT|their.show|THEIR|subs|TANCE|still|LIVES|sweet)  [rank=117           meter=++--+-+-+-   stress=++++++-+++  score=11           is_bounded=False   w_peak=1           w_stress=5         s_unstress=1       unres_across=4    ],
#  (Parse: LEESE.BUT|their.show|THEIR.SUBS|tance|STILL.LIVES|sweet)  [rank=118           meter=++--++-++-   stress=++++++-+++  score=11           is_bounded=False   w_stress=3         unres_across=8    ],
#  (Parse: leese|BUT|their|SHOW|their.subs|TANCE|still.lives|SWEET)  [rank=119           meter=-+-+--+--+   stress=++++++-+++  score=12           is_bounded=False   w_peak=1           w_stress=6         s_unstress=1       unres_across=4    ],
#  (Parse: leese|BUT|their.show|THEIR|subs|TANCE|still.lives|SWEET)  [rank=120           meter=-+--+-+--+   stress=++++++-+++  score=12           is_bounded=False   w_peak=1           w_stress=6         s_unstress=1       unres_across=4    ],
#  (Parse: leese|BUT|their.show|THEIR|subs.tance|STILL|lives.sweet)  [rank=121           meter=-+--+--+--   stress=++++++-+++  score=12           is_bounded=False   w_peak=1           w_stress=6         unres_across=4     unres_within=1    ],
#  (Parse: leese|BUT|their.show|THEIR.SUBS|tance.still|LIVES.SWEET)  [rank=122           meter=-+--++--++   stress=++++++-+++  score=12           is_bounded=False   w_stress=4         unres_across=8    ],
#  (Parse: leese|BUT.THEIR|show.their|SUBS|tance.still|LIVES.SWEET)  [rank=123           meter=-++--+--++   stress=++++++-+++  score=12           is_bounded=False   w_stress=4         unres_across=8    ],
#  (Parse: leese|BUT.THEIR|show.their|SUBS.TANCE|still|LIVES.SWEET)  [rank=124           meter=-++--++-++   stress=++++++-+++  score=12           is_bounded=False   w_stress=4         s_unstress=1       unres_across=6     unres_within=1    ],
#  (Parse: leese.but|THEIR|show|THEIR|subs|TANCE|still.lives|SWEET)  [rank=125           meter=--+-+-+--+   stress=++++++-+++  score=12           is_bounded=False   w_peak=1           w_stress=6         s_unstress=1       unres_across=4    ],
#  (Parse: leese.but|THEIR|show|THEIR|subs.tance|STILL|lives.sweet)  [rank=126           meter=--+-+--+--   stress=++++++-+++  score=12           is_bounded=False   w_peak=1           w_stress=6         unres_across=4     unres_within=1    ],
#  (Parse: leese.but|THEIR|show|THEIR.SUBS|tance.still|LIVES.SWEET)  [rank=127           meter=--+-++--++   stress=++++++-+++  score=12           is_bounded=False   w_stress=4         unres_across=8    ],
#  (Parse: leese.but|THEIR|show.their|SUBS|tance|STILL|lives.sweet)  [rank=128           meter=--+--+-+--   stress=++++++-+++  score=12           is_bounded=False   w_stress=6         unres_across=6    ],
#  (Parse: leese.but|THEIR|show.their|SUBS|tance.still|LIVES|sweet)  [rank=129           meter=--+--+--+-   stress=++++++-+++  score=12           is_bounded=False   w_stress=6         unres_across=6    ],
#  (Parse: leese.but|THEIR|show.their|SUBS.TANCE|still|LIVES|sweet)  [rank=130           meter=--+--++-+-   stress=++++++-+++  score=12           is_bounded=False   w_stress=6         s_unstress=1       unres_across=4     unres_within=1    ],
#  (Parse: leese.but|THEIR.SHOW|their|SUBS|tance.still|LIVES.SWEET)  [rank=131           meter=--++-+--++   stress=++++++-+++  score=12           is_bounded=False   w_stress=4         unres_across=8    ],
#  (Parse: leese.but|THEIR.SHOW|their|SUBS.TANCE|still|LIVES.SWEET)  [rank=132           meter=--++-++-++   stress=++++++-+++  score=12           is_bounded=False   w_stress=4         s_unstress=1       unres_across=6     unres_within=1    ],
#  (Parse: LEESE|but|THEIR.SHOW|their.subs|TANCE|still|LIVES.SWEET)  [rank=133           meter=+-++--+-++   stress=++++++-+++  score=12           is_bounded=False   w_peak=1           w_stress=4         s_unstress=1       unres_across=6    ],
#  (Parse: LEESE|but|THEIR.SHOW|their.subs|TANCE.STILL|lives|SWEET)  [rank=134           meter=+-++--++-+   stress=++++++-+++  score=12           is_bounded=False   w_peak=1           w_stress=4         s_unstress=1       unres_across=6    ],
#  (Parse: LEESE|but.their|SHOW|their.subs|TANCE|still|LIVES|sweet)  [rank=135           meter=+--+--+-+-   stress=++++++-+++  score=12           is_bounded=False   w_peak=1           w_stress=6         s_unstress=1       unres_across=4    ],
#  (Parse: LEESE|but.their|SHOW.THEIR|subs|TANCE|still|LIVES.SWEET)  [rank=136           meter=+--++-+-++   stress=++++++-+++  score=12           is_bounded=False   w_peak=1           w_stress=4         s_unstress=1       unres_across=6    ],
#  (Parse: LEESE|but.their|SHOW.THEIR|subs|TANCE.STILL|lives|SWEET)  [rank=137           meter=+--++-++-+   stress=++++++-+++  score=12           is_bounded=False   w_peak=1           w_stress=4         s_unstress=1       unres_across=6    ],
#  (Parse: LEESE|but.their|SHOW.THEIR|subs.tance|STILL.LIVES|sweet)  [rank=138           meter=+--++--++-   stress=++++++-+++  score=12           is_bounded=False   w_peak=1           w_stress=4         unres_across=6     unres_within=1    ],
#  (Parse: LEESE.BUT|their|SHOW|their.subs|TANCE|still|LIVES.SWEET)  [rank=139           meter=++-+--+-++   stress=++++++-+++  score=12           is_bounded=False   w_peak=1           w_stress=4         s_unstress=1       unres_across=6    ],
#  (Parse: LEESE.BUT|their|SHOW|their.subs|TANCE.STILL|lives|SWEET)  [rank=140           meter=++-+--++-+   stress=++++++-+++  score=12           is_bounded=False   w_peak=1           w_stress=4         s_unstress=1       unres_across=6    ],
#  (Parse: LEESE.BUT|their|SHOW.THEIR|subs|TANCE|still.lives|SWEET)  [rank=141           meter=++-++-+--+   stress=++++++-+++  score=12           is_bounded=False   w_peak=1           w_stress=4         s_unstress=1       unres_across=6    ],
#  (Parse: LEESE.BUT|their|SHOW.THEIR|subs.tance|STILL|lives.sweet)  [rank=142           meter=++-++--+--   stress=++++++-+++  score=12           is_bounded=False   w_peak=1           w_stress=4         unres_across=6     unres_within=1    ],
#  (Parse: LEESE.BUT|their.show|THEIR|subs|TANCE|still|LIVES.SWEET)  [rank=143           meter=++--+-+-++   stress=++++++-+++  score=12           is_bounded=False   w_peak=1           w_stress=4         s_unstress=1       unres_across=6    ],
#  (Parse: LEESE.BUT|their.show|THEIR|subs|TANCE.STILL|lives|SWEET)  [rank=144           meter=++--+-++-+   stress=++++++-+++  score=12           is_bounded=False   w_peak=1           w_stress=4         s_unstress=1       unres_across=6    ],
#  (Parse: LEESE.BUT|their.show|THEIR|subs.tance|STILL.LIVES|sweet)  [rank=145           meter=++--+--++-   stress=++++++-+++  score=12           is_bounded=False   w_peak=1           w_stress=4         unres_across=6     unres_within=1    ],
#  (Parse: LEESE.BUT|their.show|THEIR.SUBS|tance|STILL|lives.sweet)  [rank=146           meter=++--++-+--   stress=++++++-+++  score=12           is_bounded=False   w_stress=4         unres_across=8    ],
#  (Parse: LEESE.BUT|their.show|THEIR.SUBS|tance.still|LIVES|sweet)  [rank=147           meter=++--++--+-   stress=++++++-+++  score=12           is_bounded=False   w_stress=4         unres_across=8    ],
#  (Parse: leese|BUT|their|SHOW.THEIR|subs|TANCE.STILL|lives.sweet)  [rank=148           meter=-+-++-++--   stress=++++++-+++  score=13           is_bounded=False   w_peak=1           w_stress=5         s_unstress=1       unres_across=6    ],
#  (Parse: leese|BUT.THEIR|show|THEIR|subs|TANCE.STILL|lives.sweet)  [rank=149           meter=-++-+-++--   stress=++++++-+++  score=13           is_bounded=False   w_peak=1           w_stress=5         s_unstress=1       unres_across=6    ],
#  (Parse: leese|BUT.THEIR|show.their|SUBS.TANCE|still.lives|SWEET)  [rank=150           meter=-++--++--+   stress=++++++-+++  score=13           is_bounded=False   w_stress=5         s_unstress=1       unres_across=6     unres_within=1    ],
#  (Parse: leese.but|THEIR|show.their|SUBS|tance.still|LIVES.SWEET)  [rank=151           meter=--+--+--++   stress=++++++-+++  score=13           is_bounded=False   w_stress=5         unres_across=8    ],
#  (Parse: leese.but|THEIR|show.their|SUBS.TANCE|still|LIVES.SWEET)  [rank=152           meter=--+--++-++   stress=++++++-+++  score=13           is_bounded=False   w_stress=5         s_unstress=1       unres_across=6     unres_within=1    ],
#  (Parse: leese.but|THEIR.SHOW|their|SUBS.TANCE|still.lives|SWEET)  [rank=153           meter=--++-++--+   stress=++++++-+++  score=13           is_bounded=False   w_stress=5         s_unstress=1       unres_across=6     unres_within=1    ],
#  (Parse: LEESE|but|THEIR.SHOW|their.subs|TANCE|still.lives|SWEET)  [rank=154           meter=+-++--+--+   stress=++++++-+++  score=13           is_bounded=False   w_peak=1           w_stress=5         s_unstress=1       unres_across=6    ],
#  (Parse: LEESE|but.their|SHOW|their.subs|TANCE|still|LIVES.SWEET)  [rank=155           meter=+--+--+-++   stress=++++++-+++  score=13           is_bounded=False   w_peak=1           w_stress=5         s_unstress=1       unres_across=6    ],
#  (Parse: LEESE|but.their|SHOW|their.subs|TANCE.STILL|lives|SWEET)  [rank=156           meter=+--+--++-+   stress=++++++-+++  score=13           is_bounded=False   w_peak=1           w_stress=5         s_unstress=1       unres_across=6    ],
#  (Parse: LEESE|but.their|SHOW.THEIR|subs|TANCE|still.lives|SWEET)  [rank=157           meter=+--++-+--+   stress=++++++-+++  score=13           is_bounded=False   w_peak=1           w_stress=5         s_unstress=1       unres_across=6    ],
#  (Parse: LEESE|but.their|SHOW.THEIR|subs.tance|STILL|lives.sweet)  [rank=158           meter=+--++--+--   stress=++++++-+++  score=13           is_bounded=False   w_peak=1           w_stress=5         unres_across=6     unres_within=1    ],
#  (Parse: LEESE.BUT|their|SHOW|their.subs|TANCE|still.lives|SWEET)  [rank=159           meter=++-+--+--+   stress=++++++-+++  score=13           is_bounded=False   w_peak=1           w_stress=5         s_unstress=1       unres_across=6    ],
#  (Parse: LEESE.BUT|their.show|THEIR|subs|TANCE|still.lives|SWEET)  [rank=160           meter=++--+-+--+   stress=++++++-+++  score=13           is_bounded=False   w_peak=1           w_stress=5         s_unstress=1       unres_across=6    ],
#  (Parse: LEESE.BUT|their.show|THEIR|subs.tance|STILL|lives.sweet)  [rank=161           meter=++--+--+--   stress=++++++-+++  score=13           is_bounded=False   w_peak=1           w_stress=5         unres_across=6     unres_within=1    ],
#  (Parse: LEESE.BUT|their.show|THEIR.SUBS|tance.still|LIVES.SWEET)  [rank=162           meter=++--++--++   stress=++++++-+++  score=13           is_bounded=False   w_stress=3         unres_across=10   ],
#  (Parse: leese|BUT|their|SHOW|their.subs|TANCE.STILL|lives.sweet)  [rank=163           meter=-+-+--++--   stress=++++++-+++  score=14           is_bounded=False   w_peak=1           w_stress=6         s_unstress=1       unres_across=6    ],
#  (Parse: leese|BUT|their.show|THEIR|subs|TANCE.STILL|lives.sweet)  [rank=164           meter=-+--+-++--   stress=++++++-+++  score=14           is_bounded=False   w_peak=1           w_stress=6         s_unstress=1       unres_across=6    ],
#  (Parse: leese.but|THEIR|show|THEIR|subs|TANCE.STILL|lives.sweet)  [rank=165           meter=--+-+-++--   stress=++++++-+++  score=14           is_bounded=False   w_peak=1           w_stress=6         s_unstress=1       unres_across=6    ],
#  (Parse: leese.but|THEIR|show.their|SUBS.TANCE|still.lives|SWEET)  [rank=166           meter=--+--++--+   stress=++++++-+++  score=14           is_bounded=False   w_stress=6         s_unstress=1       unres_across=6     unres_within=1    ],
#  (Parse: leese.but|THEIR.SHOW|their.subs|TANCE|still|LIVES|sweet)  [rank=167           meter=--++--+-+-   stress=++++++-+++  score=14           is_bounded=False   w_peak=1           w_stress=6         s_unstress=1       unres_across=6    ],
#  (Parse: LEESE|but.their|SHOW|their.subs|TANCE|still.lives|SWEET)  [rank=168           meter=+--+--+--+   stress=++++++-+++  score=14           is_bounded=False   w_peak=1           w_stress=6         s_unstress=1       unres_across=6    ],
#  (Parse: LEESE.BUT|their|SHOW.THEIR|subs|TANCE.STILL|lives.sweet)  [rank=169           meter=++-++-++--   stress=++++++-+++  score=14           is_bounded=False   w_peak=1           w_stress=4         s_unstress=1       unres_across=8    ],
#  (Parse: leese.but|THEIR.SHOW|their.subs|TANCE|still|LIVES.SWEET)  [rank=170           meter=--++--+-++   stress=++++++-+++  score=15           is_bounded=False   w_peak=1           w_stress=5         s_unstress=1       unres_across=8    ],
#  (Parse: leese.but|THEIR.SHOW|their.subs|TANCE.STILL|lives|SWEET)  [rank=171           meter=--++--++-+   stress=++++++-+++  score=15           is_bounded=False   w_peak=1           w_stress=5         s_unstress=1       unres_across=8    ],
#  (Parse: LEESE|but|THEIR.SHOW|their.subs|TANCE.STILL|lives.sweet)  [rank=172           meter=+-++--++--   stress=++++++-+++  score=15           is_bounded=False   w_peak=1           w_stress=5         s_unstress=1       unres_across=8    ],
#  (Parse: LEESE|but.their|SHOW.THEIR|subs|TANCE.STILL|lives.sweet)  [rank=173           meter=+--++-++--   stress=++++++-+++  score=15           is_bounded=False   w_peak=1           w_stress=5         s_unstress=1       unres_across=8    ],
#  (Parse: LEESE.BUT|their|SHOW|their.subs|TANCE.STILL|lives.sweet)  [rank=174           meter=++-+--++--   stress=++++++-+++  score=15           is_bounded=False   w_peak=1           w_stress=5         s_unstress=1       unres_across=8    ],
#  (Parse: LEESE.BUT|their.show|THEIR|subs|TANCE.STILL|lives.sweet)  [rank=175           meter=++--+-++--   stress=++++++-+++  score=15           is_bounded=False   w_peak=1           w_stress=5         s_unstress=1       unres_across=8    ],
#  (Parse: leese.but|THEIR.SHOW|their.subs|TANCE|still.lives|SWEET)  [rank=176           meter=--++--+--+   stress=++++++-+++  score=16           is_bounded=False   w_peak=1           w_stress=6         s_unstress=1       unres_across=8    ],
#  (Parse: LEESE|but.their|SHOW|their.subs|TANCE.STILL|lives.sweet)  [rank=177           meter=+--+--++--   stress=++++++-+++  score=16           is_bounded=False   w_peak=1           w_stress=6         s_unstress=1       unres_across=8    ],
#  (Parse: leese.but|THEIR.SHOW|their.subs|TANCE.STILL|lives.sweet)  [rank=178           meter=--++--++--   stress=++++++-+++  score=18           is_bounded=False   w_peak=1           w_stress=6         s_unstress=1       unres_across=10   ]]
