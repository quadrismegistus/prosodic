# %%
# !rm -rf /Users/ryan/prosodic_data/data/english_wordforms.sqlitedict
# !pip install -qU pip wheel
# !pip install -qU -r ../requirements.txt
import sys; sys.path.insert(0,'..')
from prosodic.imports import *

# %%
x="""
Those hours, that with gentle work did frame
The lovely gaze where every eye doth dwell,
Will play the tyrants to the very same
And that unfair which fairly doth excel;
For never-resting time leads summer on
To hideous winter, and confounds him there;
Sap checked with frost, and lusty leaves quite gone,
Beauty o’er-snowed and bareness every where:
Then were not summer’s distillation left,
A liquid prisoner pent in walls of glass,
Beauty’s effect with beauty were bereft,
Nor it, nor no remembrance what it was:
But flowers distill’d, though they with winter meet,
Leese but their show; their substance still lives sweet.
"""

# %%
# %%timeit
t=Text(x)
l = t.lines[0]
parses = l.parses
# Out:
# ...
# Bounding parses: 100%|██████████| 2304/2304 [00:00<00:00, 5102.64it/s]
# 576 ms ± 2.82 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
l.best_parses
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/ryan/github/prosodic/notebooks/dev_newprosodic2.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/Users/ryan/github/prosodic/notebooks/dev_newprosodic2.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> l.best_parses
#
# NameError: name 'l' is not defined

# %%
l.bounded_parses
# Out:
#                                                rank       meter      stress  score  is_bounded  w_stress  s_unstress  w_peak  unres_across  unres_within
# parse
# those|HO|urs|THAT|with|GEN|tle|WORK|did|FRAME     4  -+-+-+-+-+  ++---+-+-+      2           1         1           1       0             0             0
# those|HO|urs|THAT|with|GEN|tle|WORK|did|FRAME     5  -+-+-+-+-+  ++-+++-+-+      2           1         2           0       0             0             0
# those|HO|urs|THAT|with|GEN|tle|WORK|did|FRAME     6  -+-+-+-+-+  ++-+-+-+++      2           1         2           0       0             0             0
# THOSE|hours|THAT|with|GEN|tle|WORK|did|FRAME      7   +-+-+-+-+   ++--+-+-+      2           1         1           1       0             0             0
# THOSE|hours|THAT|with|GEN|tle|WORK|did|FRAME      8   +-+-+-+-+   +++++-+-+      2           1         2           0       0             0             0
# ...

# %%
l.parses
# Out:
#                                                rank       meter      stress  score  w_stress  is_bounded  s_unstress  unres_across  w_peak  unres_within
# parse
# those|HO|urs|THAT|with|GEN|tle|WORK|did|FRAME     1  -+-+-+-+-+  ++-+-+-+-+      1         1           0           0             0       0             0
# THOSE|hours|THAT|with|GEN|tle|WORK|did|FRAME      2   +-+-+-+-+   +++-+-+-+      1         1           0           0             0       0             0
# those|HOURS|that.with|GEN|tle|WORK|did|FRAME      3   -+--+-+-+   ++--+-+-+      1         1           0           0             0       0             0
# those|HO|urs|THAT|with|GEN|tle|WORK|did|FRAME     4  -+-+-+-+-+  ++---+-+-+      2         1           1           1             0       0             0
# those|HO|urs|THAT|with|GEN|tle|WORK|did|FRAME     5  -+-+-+-+-+  ++-+++-+-+      2         2           1           0             0       0             0
# ...

# %%
def average_position_size(self):
    l = [len(mpos.children) for mpos in self.positions if mpos.children]
    return np.mean(l) if len(l) else np.nan

# %%
average_position_size(bp1), average_position_size(bp2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/ryan/github/prosodic/notebooks/dev_newprosodic2.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell:/Users/ryan/github/prosodic/notebooks/dev_newprosodic2.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> average_position_size(bp1), average_position_size(bp2)
#
# NameError: name 'bp1' is not defined

# %%
# l.parse(max_s=None, max_w=None)
.positions
# Out:
#   Cell In[6], line 2
#     .positions
#     ^
# SyntaxError: invalid syntax

# %%
# l.bound_parses(l.all_parses)
len(l.bounded_parses)
# Out:
# Scanning parses: 100%|██████████| 2304/2304 [00:00<00:00, 21796.95it/s]
# 2299

# %%
len(l.parses)
# Out:
# 2304

# %%
l.parses
# Out:
# [(Parse: those|HOURS|that.with|GEN|tle|WORK|did|FRAME) [rank=1 meter=-+--+-+-+ stress=++--+-+-+ score=1 w_stress=1],
#  (Parse: those|HO|urs|THAT|with|GEN|tle|WORK|did|FRAME) [rank=2 meter=-+-+-+-+-+ stress=++-+-+-+-+ score=1 w_stress=1],
#  (Parse: THOSE|hours|THAT|with|GEN|tle|WORK|did|FRAME) [rank=3 meter=+-+-+-+-+ stress=+++-+-+-+ score=1 w_stress=1],
#  (Parse: those|HO|urs|THAT|with|GEN|tle|WORK|did|FRAME) [rank=4 meter=-+-+-+-+-+ stress=++---+-+-+ score=2 is_bounded=True w_stress=1 s_unstress=1],
#  (Parse: those|HOURS|that.with|GEN|tle|WORK|did|FRAME) [rank=5 meter=-+--+-+-+ stress=++--+-+++ score=2 is_bounded=True w_stress=2],
#  (Parse: those|HO|urs|THAT|with|GEN|tle|WORK|did|FRAME) [rank=6 meter=-+-+-+-+-+ stress=++-+++-+-+ score=2 is_bounded=True w_stress=2],
#  (Parse: those|HO|urs|THAT|with|GEN|tle|WORK|did|FRAME) [rank=7 meter=-+-+-+-+-+ stress=++-+-+-+++ score=2 is_bounded=True w_stress=2],
# ...

# %%
# %%timeit -n 1 -r 1
l.bound_parses(poss_parses)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/ryan/github/prosodic/notebooks/dev_newprosodic2.ipynb Cell 9 line 2
#       <a href='vscode-notebook-cell:/Users/ryan/github/prosodic/notebooks/dev_newprosodic2.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> # %%timeit -n 1 -r 1
# ----> <a href='vscode-notebook-cell:/Users/ryan/github/prosodic/notebooks/dev_newprosodic2.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> l.bound_parses(poss_parses)
#
# NameError: name 'poss_parses' is not defined

# %%
l.scansions
# Out:
# [(Parse: leese|BUT|their|SHOW|their|SUBS|tance|STILL|lives|SWEET)  [rank=1             meter=-+-+-+-+-+   stress=++++++-+++  score=4            is_bounded=False   w_stress=4        ],
#  (Parse: LEESE|but|THEIR|show|THEIR.SUBS|tance|STILL|lives|SWEET)  [rank=2             meter=+-+-++-+-+   stress=++++++-+++  score=5            is_bounded=False   w_stress=3         unres_across=2    ],
#  (Parse: LEESE|but|THEIR.SHOW|their|SUBS|tance|STILL|lives|SWEET)  [rank=3             meter=+-++-+-+-+   stress=++++++-+++  score=5            is_bounded=False   w_stress=3         unres_across=2    ],
#  (Parse: LEESE.BUT|their|SHOW|their|SUBS|tance|STILL|lives|SWEET)  [rank=4             meter=++-+-+-+-+   stress=++++++-+++  score=5            is_bounded=False   w_stress=3         unres_across=2    ],
# ...
