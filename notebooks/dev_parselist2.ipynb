# %%
import sys; sys.path.insert(0,'..')
from prosodic import *

# %%
line = Line("Of man's first disobedience, and the fruit")
line
# Out:
# Line(txt="Of man's first disobedience, and the fruit")

# %%
line.parses
# Out:
# ParseList(num_parses=1, num_all_parses=2)

# %%
parse1 = line.parses[0]
parse1
# Out:
# Parse(txt="of MAN'S first DI so BE dien CE and.the FRUIT", rank=1, meter='-+-+-+-+--+', stress='-+++-+----+', score=2, is_bounded=0)

# %%
parse2 = line.parses[1]
parse2
# Out:
# Parse(txt="of MAN'S first DI so BE dien CE and THE fruit", rank=2, meter='-+-+-+-+-+-', stress='-+++-+----+', score=4, is_bounded=1)

# %%
parse1.bounds(parse2)
# Out:
# True
