# %%
# !rm -rf /Users/ryan/prosodic_data/data/english_wordtypes
import sys; sys.path.insert(0,'..')
from prosodic.imports import *

# %%
type(Text('hello world').words)
# Out:
# prosodic.texts.LineList

# %%
type(Text('hello world').children)
# Out:
# prosodic.texts.StanzaList

# %%
line=Line(sonnet.strip().split('\n')[0])
# parse=Parse(line.txt, 'wwswwswwsw')
# line.wordform_matrix

# %%
x=line.parse(max_w=1, max_s=1)
# Out:
# 2023-10-04 16:44:08.548 | parse | Set meter to: Meter(constraints=('w_peak', 'w_stress', 's_unstress', 'unres_across', 'unres_within', 'foot_size'), categorical_constraints=('foot_size',), max_s=1, max_w=1, resolve_optionality=True) | meter.py:83
# 2023-10-04 16:44:08.549 | iter_parses | Generated 32 from a wordfrom matrix of size (16, THOSE HO.urs that with GEN.tle WORK did FRAME, 10, 1, 1, 178) | meter.py:105
# 2023-10-04 16:44:08.555 | iter_parses | Returning 32 parses | meter.py:110
# 2023-10-04 16:44:08.556 | parse | Returned 32 parses | meter.py:85

# %%
line.parse(max_s=1, max_w=1, constraints=('w_peak','unres_across','unres_within',))
# Out:
# 2023-10-04 16:44:12.515 | parse | Set meter to: Meter(constraints=('w_peak', 'unres_across', 'unres_within'), categorical_constraints=('foot_size',), max_s=1, max_w=1, resolve_optionality=True) | meter.py:83
# 2023-10-04 16:44:12.516 | iter_parses | Generated 32 from a wordfrom matrix of size (16, THOSE HO.urs that with GEN.tle WORK did FRAME, 10, 1, 1, 178) | meter.py:105
# 2023-10-04 16:44:12.521 | iter_parses | Returning 32 parses | meter.py:110
# 2023-10-04 16:44:12.521 | parse | Returned 32 parses | meter.py:85
# ParseList(num_parses=16, num_all_parses=16)

# %%
# line.best_parses
# line.parses

# %%
t=Text('\n'.join(sonnet.strip().split('\n')[:4]))
t
# Out:
# Text()

# %%
t.parse(progress=True)
# Out:
# Parsing lines:   0%|          | 0/4 [00:00<?, ?it/s]2023-10-04 16:43:10.909 | parse | Set meter to: Meter(constraints=('w_peak', 'w_stress', 's_unstress', 'unres_across', 'unres_within', 'foot_size'), categorical_constraints=('foot_size',), max_s=2, max_w=2, resolve_optionality=True) | meter.py:83
# 2023-10-04 16:43:10.912 | iter_parses | Generated 2304 from a wordfrom matrix of size (16, THOSE HO.urs that with GEN.tle WORK did FRAME, 10, 2, 2, 178) | meter.py:105
# 2023-10-04 16:43:11.242 | iter_parses | Returning 2304 parses | meter.py:110
# 2023-10-04 16:43:11.242 | parse | Returned 2304 parses | meter.py:85
# Parsing lines:  25%|██▌       | 1/4 [00:00<00:01,  2.43it/s]2023-10-04 16:43:11.322 | parse | Set meter to: Meter(constraints=('w_peak', 'w_stress', 's_unstress', 'unres_across', 'unres_within', 'foot_size'), categorical_constraints=('foot_size',), max_s=2, max_w=2, resolve_optionality=True) | meter.py:83
# 2023-10-04 16:43:11.324 | iter_parses | Generated 932 from a wordfrom matrix of size (4, the LO.vely GAZE WHERE E.very EYE doth DWELL, 10, 2, 2, 178) | meter.py:105
# 2023-10-04 16:43:11.551 | iter_parses | Returning 932 parses | meter.py:110
# 2023-10-04 16:43:11.551 | parse | Returned 932 parses | meter.py:85
# Parsing lines:  50%|█████     | 2/4 [00:00<00:00,  3.09it/s]2023-10-04 16:43:11.584 | parse | Set meter to: Meter(constraints=('w_peak', 'w_stress', 's_unstress', 'unres_across', 'unres_within', 'foot_size'), categorical_constraints=('foot_size',), max_s=2, max_w=2, resolve_optionality=True) | meter.py:83
# 2023-10-04 16:43:11.585 | iter_parses | Generated 2848 from a wordfrom matrix of size (16, will PLAY the TY.rants to the VE.ry SAME, 10, 2, 2, 178) | meter.py:105
# 2023-10-04 16:43:12.283 | iter_parses | Returning 2848 parses | meter.py:110
# 2023-10-04 16:43:12.283 | parse | Returned 2848 parses | meter.py:85
# Parsing lines:  75%|███████▌  | 3/4 [00:01<00:00,  1.85it/s]2023-10-04 16:43:12.382 | parse | Set meter to: Meter(constraints=('w_peak', 'w_stress', 's_unstress', 'unres_across', 'unres_within', 'foot_size'), categorical_constraints=('foot_size',), max_s=2, max_w=2, resolve_optionality=True) | meter.py:83
# 2023-10-04 16:43:12.383 | iter_parses | Generated 2136 from a wordfrom matrix of size (12, and that un.FAIR WHICH FAIR.ly doth ex.CEL, 10, 2, 2, 178) | meter.py:105
# 2023-10-04 16:43:12.905 | iter_parses | Returning 2136 parses | meter.py:110
# 2023-10-04 16:43:12.906 | parse | Returned 2136 parses | meter.py:85
# Parsing lines: 100%|██████████| 4/4 [00:02<00:00,  1.93it/s]
# ParseList(num_parses=4, num_all_parses=4)

# %%
t.parse_stats
# Out:
#                                                                                                                 bestparse_nsylls  parses_ncombo  parses_nparse  parses_nviols  parses_w_peak  \
# stanza_num line_num line_txt                                     bestparse_txt
# 1          1        Those hours, that with gentle work did frame those HO urs THAT with GEN tle WORK did FRAME                10           16.0            5.0       0.248227            0.0
#            2        The lovely gaze where every eye doth dwell,  the LO vely GAZE where E very EYE doth DWELL                 10            4.0            1.0       0.166667            0.0
#            3        Will play the tyrants to the very same       will PLAY the TY rants TO the VE ry SAME                     10           16.0            1.0       0.000000            0.0
#            4        And that unfair which fairly doth excel;     and THAT un FAIR which FAIR ly DOTH ex CEL                   10           12.0            1.0       0.333333            0.0
#
#                                                                                                                 parses_w_stress  parses_s_unstress  parses_unres_across  parses_unres_within  \
# stanza_num line_num line_txt                                     bestparse_txt
# 1          1        Those hours, that with gentle work did frame those HO urs THAT with GEN tle WORK did FRAME         0.638298                0.0             0.851064                  0.0
#            2        The lovely gaze where every eye doth dwell,  the LO vely GAZE where E very EYE doth DWELL          1.000000                0.0             0.000000                  0.0
#            3        Will play the tyrants to the very same       will PLAY the TY rants TO the VE ry SAME              0.000000                0.0             0.000000                  0.0
#            4        And that unfair which fairly doth excel;     and THAT un FAIR which FAIR ly DOTH ex CEL            1.000000                1.0             0.000000                  0.0
#
#                                                                                                                 parses_foot_size
# stanza_num line_num line_txt                                     bestparse_txt
# 1          1        Those hours, that with gentle work did frame those HO urs THAT with GEN tle WORK did FRAME               0.0
#            2        The lovely gaze where every eye doth dwell,  the LO vely GAZE where E very EYE doth DWELL                0.0
#            3        Will play the tyrants to the very same       will PLAY the TY rants TO the VE ry SAME                    0.0
#            4        And that unfair which fairly doth excel;     and THAT un FAIR which FAIR ly DOTH ex CEL                  0.0
