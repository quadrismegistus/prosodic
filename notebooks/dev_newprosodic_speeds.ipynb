# %%
# !rm -rf /Users/ryan/prosodic_data/data/english_wordforms.sqlitedict
import sys; sys.path.insert(0,'..')
from prosodic.imports import *

# %%
t = Text("""
Those hours, that with gentle work did frame
The lovely gaze where every eye doth dwell,
Will play the tyrants to the very same
And that unfair which fairly doth excel;
For never-resting time leads summer on
To hideous winter, and confounds him there;
Sap checked with frost, and lusty leaves quite gone,
Beauty o’er-snowed and bareness every where:
Then were not summer’s distillation left,
A liquid prisoner pent in walls of glass,
Beauty’s effect with beauty were bereft,
Nor it, nor no remembrance what it was:
But flowers distill’d, though they with winter meet,
Leese but their show; their substance still lives sweet.
""")

# %%
t.parses_df
# Out:
#                                                                                                                                          nsylls  ncombo  nparse nviols w_peak w_stress s_unstress  \
# stanza_i sent_i sentpart_i line_i txt                                                parse
# 1        1      1          1      Those hours, that with gentle work did frame       those HO urs THAT with GEN tle WORK did FRAME           10    16.0     2.0    0.4             0.5        1.0
#                 2          2      The lovely gaze where every eye doth dwell,        the LO vely GAZE where E very EYE doth DWELL            10     4.0     1.0    0.2             1.0
#                 3          3      Will play the tyrants to the very same             will PLAY the TY rants TO the VE ry SAME                10    16.0     1.0    0.2                        1.0
#                            4      And that unfair which fairly doth excel;           and THAT un FAIR which FAIR ly DOTH ex CEL              10    12.0     1.0    0.5             1.0        2.0
#                 4          5      For never-resting time leads summer on             for NE ver RES ting TIME leads SUM mer ON               10     2.0     1.0    0.2             1.0
#                            6      To hideous winter, and confounds him there;        to HI deo.us WIN ter AND con FOUNDS him THERE           11     7.3     2.7    0.6    0.3      0.3        1.8
#                 6          7      Sap checked with frost, and lusty leaves quite ... sap CHECKED with FROST and LUS ty LEAVES quite ...      10     4.0     2.0    0.4             1.5
#                 8          8      Beauty o'er-snowed and bareness every where:       BEA uty.o'er SNOWED and BA reness E very WHERE          10    12.0     3.0    0.4    0.3      0.3        0.7
#                 9          9      Then were not summer's distillation left,          THEN were NOT.SUM mer's DIS til LA tion LEFT            10     2.0     3.0    0.4    0.3      1.0        0.3
#                 10         10     A liquid prisoner pent in walls of glass,          a LI quid PRI soner PENT in WALLS of GLASS              10    16.0     1.0
#                 11         11     Beauty's effect with beauty were bereft,           BEA uty's EF.FECT with BEA uty WERE be REFT             10     8.0     4.0    0.5    0.2      0.2        1.8
#                 12         12     Nor it, nor no remembrance what it was:            NOR it NOR.NO re MEM brance WHAT it.was                 10     8.0     3.0    0.4             1.0        0.7
#                 14         13     But flowers distill'd, though they with winter ... BUT flo WERS dis TILL'D though THEY with WIN te...      11     1.8     5.5    0.7    0.2      1.5        0.6
#                 16         14     Leese but their show; their substance still liv... leese BUT their SHOW their SUBS tance STILL liv...      10     1.0     7.0    1.0             3.4
#
#                                                                                                                                         unres_across unres_within foot_size
# stanza_i sent_i sentpart_i line_i txt                                                parse
# 1        1      1          1      Those hours, that with gentle work did frame       those HO urs THAT with GEN tle WORK did FRAME               1.0
#                 2          2      The lovely gaze where every eye doth dwell,        the LO vely GAZE where E very EYE doth DWELL
#                 3          3      Will play the tyrants to the very same             will PLAY the TY rants TO the VE ry SAME
#                            4      And that unfair which fairly doth excel;           and THAT un FAIR which FAIR ly DOTH ex CEL
#                 4          5      For never-resting time leads summer on             for NE ver RES ting TIME leads SUM mer ON
#                            6      To hideous winter, and confounds him there;        to HI deo.us WIN ter AND con FOUNDS him THERE               0.6          0.3
#                 6          7      Sap checked with frost, and lusty leaves quite ... sap CHECKED with FROST and LUS ty LEAVES quite ...          1.0
#                 8          8      Beauty o'er-snowed and bareness every where:       BEA uty.o'er SNOWED and BA reness E very WHERE              0.7          0.3
#                 9          9      Then were not summer's distillation left,          THEN were NOT.SUM mer's DIS til LA tion LEFT                0.7          0.3
#                 10         10     A liquid prisoner pent in walls of glass,          a LI quid PRI soner PENT in WALLS of GLASS
#                 11         11     Beauty's effect with beauty were bereft,           BEA uty's EF.FECT with BEA uty WERE be REFT                 0.5          0.5
#                 12         12     Nor it, nor no remembrance what it was:            NOR it NOR.NO re MEM brance WHAT it.was                     0.7          0.3
#                 14         13     But flowers distill'd, though they with winter ... BUT flo WERS dis TILL'D though THEY with WIN te...          1.2          0.5
#                 16         14     Leese but their show; their substance still liv... leese BUT their SHOW their SUBS tance STILL liv...          2.3

# %%
# %%timeit
t.parse(max_s=2,max_w=2,resolve_optionality=False)
# Out:
# Parsing lines: 100%|██████████| 14/14 [00:00<00:00, 25.70it/s]
#                                                                                                                                          nsylls  ncombo  nparse nviols w_peak w_stress s_unstress  \
# stanza_i sent_i sentpart_i line_i txt                                                parse
# 1        1      1          1      Those hours, that with gentle work did frame       those HO urs THAT with GEN tle WORK did FRAME           10    16.0     2.0    0.4             0.5        1.0
#                 2          2      The lovely gaze where every eye doth dwell,        the LO vely GAZE where E very EYE doth DWELL            10     4.0     1.0    0.2             1.0
#                 3          3      Will play the tyrants to the very same             will PLAY the TY rants TO the VE ry SAME                10    16.0     1.0    0.2                        1.0
#                            4      And that unfair which fairly doth excel;           and THAT un FAIR which FAIR ly DOTH ex CEL              10    12.0     1.0    0.5             1.0        2.0
#                 4          5      For never-resting time leads summer on             for NE ver RES ting TIME leads SUM mer ON               10     2.0     1.0    0.2             1.0
#                            6      To hideous winter, and confounds him there;        to HI deo.us WIN ter AND con FOUNDS him THERE           11     7.3     2.7    0.6    0.3      0.3        1.8
#                 6          7      Sap checked with frost, and lusty leaves quite ... sap CHECKED with FROST and LUS ty LEAVES quite ...      10     4.0     2.0    0.4             1.5
#                 8          8      Beauty o'er-snowed and bareness every where:       BEA uty.o'er SNOWED and BA reness E very WHERE          10    12.0     3.0    0.4    0.3      0.3        0.7
#                 9          9      Then were not summer's distillation left,          THEN were NOT.SUM mer's DIS til LA tion LEFT            10     2.0     3.0    0.4    0.3      1.0        0.3
#                 10         10     A liquid prisoner pent in walls of glass,          a LI quid PRI soner PENT in WALLS of GLASS              10    16.0     1.0
#                 11         11     Beauty's effect with beauty were bereft,           BEA uty's EF.FECT with BEA uty WERE be REFT             10     8.0     4.0    0.5    0.2      0.2        1.8
#                 12         12     Nor it, nor no remembrance what it was:            NOR it NOR.NO re MEM brance WHAT it.was                 10     8.0     3.0    0.4             1.0        0.7
#                 14         13     But flowers distill'd, though they with winter ... BUT flo WERS dis TILL'D though THEY with WIN te...      11     1.8     5.5    0.7    0.2      1.5        0.6
#                 16         14     Leese but their show; their substance still liv... leese BUT their SHOW their SUBS tance STILL liv...      10     1.0     7.0    1.0             3.4
#
#                                                                                                                                         unres_across unres_within foot_size
# stanza_i sent_i sentpart_i line_i txt                                                parse
# 1        1      1          1      Those hours, that with gentle work did frame       those HO urs THAT with GEN tle WORK did FRAME               1.0
#                 2          2      The lovely gaze where every eye doth dwell,        the LO vely GAZE where E very EYE doth DWELL
#                 3          3      Will play the tyrants to the very same             will PLAY the TY rants TO the VE ry SAME
#                            4      And that unfair which fairly doth excel;           and THAT un FAIR which FAIR ly DOTH ex CEL
#                 4          5      For never-resting time leads summer on             for NE ver RES ting TIME leads SUM mer ON
#                            6      To hideous winter, and confounds him there;        to HI deo.us WIN ter AND con FOUNDS him THERE               0.6          0.3
#                 6          7      Sap checked with frost, and lusty leaves quite ... sap CHECKED with FROST and LUS ty LEAVES quite ...          1.0
#                 8          8      Beauty o'er-snowed and bareness every where:       BEA uty.o'er SNOWED and BA reness E very WHERE              0.7          0.3
#                 9          9      Then were not summer's distillation left,          THEN were NOT.SUM mer's DIS til LA tion LEFT                0.7          0.3
#                 10         10     A liquid prisoner pent in walls of glass,          a LI quid PRI soner PENT in WALLS of GLASS
#                 11         11     Beauty's effect with beauty were bereft,           BEA uty's EF.FECT with BEA uty WERE be REFT                 0.5          0.5
#                 12         12     Nor it, nor no remembrance what it was:            NOR it NOR.NO re MEM brance WHAT it.was                     0.7          0.3
#                 14         13     But flowers distill'd, though they with winter ... BUT flo WERS dis TILL'D though THEY with WIN te...          1.2          0.5
#                 16         14     Leese but their show; their substance still liv... leese BUT their SHOW their SUBS tance STILL liv...          2.3

# %%
# %%timeit
t.parse(max_s=2,max_w=2,resolve_optionality=True)
# Out:
# Parsing lines: 100%|██████████| 14/14 [00:05<00:00,  2.58it/s]
#                                                                                                                                          nsylls  ncombo  nparse nviols w_peak w_stress s_unstress  \
# stanza_i sent_i sentpart_i line_i txt                                                parse
# 1        1      1          1      Those hours, that with gentle work did frame       those HO urs THAT with GEN tle WORK did FRAME           10    16.0     2.0    0.4             0.5        1.0
#                 2          2      The lovely gaze where every eye doth dwell,        the LO vely GAZE where E very EYE doth DWELL            10     4.0     1.0    0.2             1.0
#                 3          3      Will play the tyrants to the very same             will PLAY the TY rants TO the VE ry SAME                10    16.0     1.0    0.2                        1.0
#                            4      And that unfair which fairly doth excel;           and THAT un FAIR which FAIR ly DOTH ex CEL              10    12.0     1.0    0.5             1.0        2.0
#                 4          5      For never-resting time leads summer on             for NE ver RES ting TIME leads SUM mer ON               10     2.0     1.0    0.2             1.0
#                            6      To hideous winter, and confounds him there;        to HI deo.us WIN ter AND con FOUNDS him THERE           11     7.3     2.7    0.6    0.3      0.3        1.8
#                 6          7      Sap checked with frost, and lusty leaves quite ... sap CHECKED with FROST and LUS ty LEAVES quite ...      10     4.0     2.0    0.4             1.5
#                 8          8      Beauty o'er-snowed and bareness every where:       BEA uty.o'er SNOWED and BA reness E very WHERE          10    12.0     3.0    0.4    0.3      0.3        0.7
#                 9          9      Then were not summer's distillation left,          THEN were NOT.SUM mer's DIS til LA tion LEFT            10     2.0     3.0    0.4    0.3      1.0        0.3
#                 10         10     A liquid prisoner pent in walls of glass,          a LI quid PRI soner PENT in WALLS of GLASS              10    16.0     1.0
#                 11         11     Beauty's effect with beauty were bereft,           BEA uty's EF.FECT with BEA uty WERE be REFT             10     8.0     4.0    0.5    0.2      0.2        1.8
#                 12         12     Nor it, nor no remembrance what it was:            NOR it NOR.NO re MEM brance WHAT it.was                 10     8.0     3.0    0.4             1.0        0.7
#                 14         13     But flowers distill'd, though they with winter ... BUT flo WERS dis TILL'D though THEY with WIN te...      11     1.8     5.5    0.7    0.2      1.5        0.6
#                 16         14     Leese but their show; their substance still liv... leese BUT their SHOW their SUBS tance STILL liv...      10     1.0     7.0    1.0             3.4
#
#                                                                                                                                         unres_across unres_within foot_size
# stanza_i sent_i sentpart_i line_i txt                                                parse
# 1        1      1          1      Those hours, that with gentle work did frame       those HO urs THAT with GEN tle WORK did FRAME               1.0
#                 2          2      The lovely gaze where every eye doth dwell,        the LO vely GAZE where E very EYE doth DWELL
#                 3          3      Will play the tyrants to the very same             will PLAY the TY rants TO the VE ry SAME
#                            4      And that unfair which fairly doth excel;           and THAT un FAIR which FAIR ly DOTH ex CEL
#                 4          5      For never-resting time leads summer on             for NE ver RES ting TIME leads SUM mer ON
#                            6      To hideous winter, and confounds him there;        to HI deo.us WIN ter AND con FOUNDS him THERE               0.6          0.3
#                 6          7      Sap checked with frost, and lusty leaves quite ... sap CHECKED with FROST and LUS ty LEAVES quite ...          1.0
#                 8          8      Beauty o'er-snowed and bareness every where:       BEA uty.o'er SNOWED and BA reness E very WHERE              0.7          0.3
#                 9          9      Then were not summer's distillation left,          THEN were NOT.SUM mer's DIS til LA tion LEFT                0.7          0.3
#                 10         10     A liquid prisoner pent in walls of glass,          a LI quid PRI soner PENT in WALLS of GLASS
#                 11         11     Beauty's effect with beauty were bereft,           BEA uty's EF.FECT with BEA uty WERE be REFT                 0.5          0.5
#                 12         12     Nor it, nor no remembrance what it was:            NOR it NOR.NO re MEM brance WHAT it.was                     0.7          0.3
#                 14         13     But flowers distill'd, though they with winter ... BUT flo WERS dis TILL'D though THEY with WIN te...          1.2          0.5
#                 16         14     Leese but their show; their substance still liv... leese BUT their SHOW their SUBS tance STILL liv...          2.3

# %%
# %%timeit
t.parse(max_s=None,max_w=None,resolve_optionality=False)
# Out:
# Parsing lines: 100%|██████████| 14/14 [00:05<00:00,  2.50it/s]
#                                                                                                                                          nsylls  ncombo  nparse nviols w_peak w_stress s_unstress  \
# stanza_i sent_i sentpart_i line_i txt                                                parse
# 1        1      1          1      Those hours, that with gentle work did frame       those HO urs THAT with GEN tle WORK did FRAME           10    16.0     2.0    0.4             0.5        1.0
#                 2          2      The lovely gaze where every eye doth dwell,        the LO vely GAZE where E very EYE doth DWELL            10     4.0     1.0    0.2             1.0
#                 3          3      Will play the tyrants to the very same             will PLAY the TY rants TO the VE ry SAME                10    16.0     1.0    0.2                        1.0
#                            4      And that unfair which fairly doth excel;           and THAT un FAIR which FAIR ly DOTH ex CEL              10    12.0     1.0    0.5             1.0        2.0
#                 4          5      For never-resting time leads summer on             for NE ver RES ting TIME leads SUM mer ON               10     2.0     1.0    0.2             1.0
#                            6      To hideous winter, and confounds him there;        to HI deo.us WIN ter AND con FOUNDS him THERE           11     7.3     2.7    0.6    0.3      0.3        1.8
#                 6          7      Sap checked with frost, and lusty leaves quite ... sap CHECKED with FROST and LUS ty LEAVES quite ...      10     4.0     2.0    0.4             1.5
#                 8          8      Beauty o'er-snowed and bareness every where:       BEA uty.o'er SNOWED and BA reness E very WHERE          10    12.0     3.0    0.4    0.3      0.3        0.7
#                 9          9      Then were not summer's distillation left,          THEN were NOT.SUM mer's DIS til LA tion LEFT            10     2.0     3.0    0.4    0.3      1.0        0.3
#                 10         10     A liquid prisoner pent in walls of glass,          a LI quid PRI soner PENT in WALLS of GLASS              10    16.0     1.0
#                 11         11     Beauty's effect with beauty were bereft,           BEA uty's EF.FECT with BEA uty WERE be REFT             10     8.0     4.0    0.5    0.2      0.2        1.8
#                 12         12     Nor it, nor no remembrance what it was:            NOR it NOR.NO re MEM brance WHAT it.was                 10     8.0     3.0    0.4             1.0        0.7
#                 14         13     But flowers distill'd, though they with winter ... BUT flo WERS dis TILL'D though THEY with WIN te...      11     1.8     5.5    0.7    0.2      1.5        0.6
#                 16         14     Leese but their show; their substance still liv... leese BUT their SHOW their SUBS tance STILL liv...      10     1.0     7.0    1.0             3.4
#
#                                                                                                                                         unres_across unres_within foot_size
# stanza_i sent_i sentpart_i line_i txt                                                parse
# 1        1      1          1      Those hours, that with gentle work did frame       those HO urs THAT with GEN tle WORK did FRAME               1.0
#                 2          2      The lovely gaze where every eye doth dwell,        the LO vely GAZE where E very EYE doth DWELL
#                 3          3      Will play the tyrants to the very same             will PLAY the TY rants TO the VE ry SAME
#                            4      And that unfair which fairly doth excel;           and THAT un FAIR which FAIR ly DOTH ex CEL
#                 4          5      For never-resting time leads summer on             for NE ver RES ting TIME leads SUM mer ON
#                            6      To hideous winter, and confounds him there;        to HI deo.us WIN ter AND con FOUNDS him THERE               0.6          0.3
#                 6          7      Sap checked with frost, and lusty leaves quite ... sap CHECKED with FROST and LUS ty LEAVES quite ...          1.0
#                 8          8      Beauty o'er-snowed and bareness every where:       BEA uty.o'er SNOWED and BA reness E very WHERE              0.7          0.3
#                 9          9      Then were not summer's distillation left,          THEN were NOT.SUM mer's DIS til LA tion LEFT                0.7          0.3
#                 10         10     A liquid prisoner pent in walls of glass,          a LI quid PRI soner PENT in WALLS of GLASS
#                 11         11     Beauty's effect with beauty were bereft,           BEA uty's EF.FECT with BEA uty WERE be REFT                 0.5          0.5
#                 12         12     Nor it, nor no remembrance what it was:            NOR it NOR.NO re MEM brance WHAT it.was                     0.7          0.3
#                 14         13     But flowers distill'd, though they with winter ... BUT flo WERS dis TILL'D though THEY with WIN te...          1.2          0.5
#                 16         14     Leese but their show; their substance still liv... leese BUT their SHOW their SUBS tance STILL liv...          2.3

# %%
# %%timeit
t.parse(max_s=None,max_w=None,resolve_optionality=True)
# Out:
# Parsing lines: 100%|██████████| 14/14 [00:36<00:00,  2.58s/it]
#                                                                                                                                          nsylls  ncombo  nparse nviols w_peak w_stress s_unstress  \
# stanza_i sent_i sentpart_i line_i txt                                                parse
# 1        1      1          1      Those hours, that with gentle work did frame       those HO urs THAT with GEN tle WORK did FRAME           10    16.0     2.0    0.4             0.5        1.0
#                 2          2      The lovely gaze where every eye doth dwell,        the LO vely GAZE where E very EYE doth DWELL            10     4.0     1.0    0.2             1.0
#                 3          3      Will play the tyrants to the very same             will PLAY the TY rants TO the VE ry SAME                10    16.0     1.0    0.2                        1.0
#                            4      And that unfair which fairly doth excel;           and THAT un FAIR which FAIR ly DOTH ex CEL              10    12.0     1.0    0.5             1.0        2.0
#                 4          5      For never-resting time leads summer on             for NE ver RES ting TIME leads SUM mer ON               10     2.0     1.0    0.2             1.0
#                            6      To hideous winter, and confounds him there;        to HI deo.us WIN ter AND con FOUNDS him THERE           11     7.3     2.7    0.6    0.3      0.3        1.8
#                 6          7      Sap checked with frost, and lusty leaves quite ... sap CHECKED with FROST and LUS ty LEAVES quite ...      10     4.0     2.0    0.4             1.5
#                 8          8      Beauty o'er-snowed and bareness every where:       BEA uty.o'er SNOWED and BA reness E very WHERE          10    12.0     3.0    0.4    0.3      0.3        0.7
#                 9          9      Then were not summer's distillation left,          THEN were NOT.SUM mer's DIS til LA tion LEFT            10     2.0     3.0    0.4    0.3      1.0        0.3
#                 10         10     A liquid prisoner pent in walls of glass,          a LI quid PRI soner PENT in WALLS of GLASS              10    16.0     1.0
#                 11         11     Beauty's effect with beauty were bereft,           BEA uty's EF.FECT with BEA uty WERE be REFT             10     8.0     4.0    0.5    0.2      0.2        1.8
#                 12         12     Nor it, nor no remembrance what it was:            NOR it NOR.NO re MEM brance WHAT it.was                 10     8.0     3.0    0.4             1.0        0.7
#                 14         13     But flowers distill'd, though they with winter ... BUT flo WERS dis TILL'D though THEY with WIN te...      11     1.8     5.5    0.7    0.2      1.5        0.6
#                 16         14     Leese but their show; their substance still liv... leese BUT their SHOW their SUBS tance STILL liv...      10     1.0     7.0    1.0             3.4
#
#                                                                                                                                         unres_across unres_within foot_size
# stanza_i sent_i sentpart_i line_i txt                                                parse
# 1        1      1          1      Those hours, that with gentle work did frame       those HO urs THAT with GEN tle WORK did FRAME               1.0
#                 2          2      The lovely gaze where every eye doth dwell,        the LO vely GAZE where E very EYE doth DWELL
#                 3          3      Will play the tyrants to the very same             will PLAY the TY rants TO the VE ry SAME
#                            4      And that unfair which fairly doth excel;           and THAT un FAIR which FAIR ly DOTH ex CEL
#                 4          5      For never-resting time leads summer on             for NE ver RES ting TIME leads SUM mer ON
#                            6      To hideous winter, and confounds him there;        to HI deo.us WIN ter AND con FOUNDS him THERE               0.6          0.3
#                 6          7      Sap checked with frost, and lusty leaves quite ... sap CHECKED with FROST and LUS ty LEAVES quite ...          1.0
#                 8          8      Beauty o'er-snowed and bareness every where:       BEA uty.o'er SNOWED and BA reness E very WHERE              0.7          0.3
#                 9          9      Then were not summer's distillation left,          THEN were NOT.SUM mer's DIS til LA tion LEFT                0.7          0.3
#                 10         10     A liquid prisoner pent in walls of glass,          a LI quid PRI soner PENT in WALLS of GLASS
#                 11         11     Beauty's effect with beauty were bereft,           BEA uty's EF.FECT with BEA uty WERE be REFT                 0.5          0.5
#                 12         12     Nor it, nor no remembrance what it was:            NOR it NOR.NO re MEM brance WHAT it.was                     0.7          0.3
#                 14         13     But flowers distill'd, though they with winter ... BUT flo WERS dis TILL'D though THEY with WIN te...          1.2          0.5
#                 16         14     Leese but their show; their substance still liv... leese BUT their SHOW their SUBS tance STILL liv...          2.3
