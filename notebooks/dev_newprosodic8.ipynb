# %%
# !rm -rf /Users/ryan/prosodic_data/data/english_wordtypes
import sys; sys.path.insert(0,'..')
from prosodic.imports import *

# %%
line=Line(sonnet.strip().split('\n')[0])
# parse=Parse(line.txt, 'wwswwswwsw')

# %%
line.parse()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /Users/ryan/github/prosodic/notebooks/dev_newprosodic8.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/Users/ryan/github/prosodic/notebooks/dev_newprosodic8.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> line.parse()
#
# File ~/github/prosodic/notebooks/../prosodic/meter.py:72, in ParseableText.parse(self, progress, bound, **meter_kwargs)
#      68 @cache
#      69 # @profile
#      70 def parse(self, progress=None, bound=True, **meter_kwargs):
#      71     from .parsing import ParseList
# ---> 72     self.set_meter(**meter_kwargs)
#      73     parses = list(self.iter_parses(progress=progress))
#      74     if bound: self.bound_parses(parses, progress=progress)
#
# File ~/github/prosodic/notebooks/../prosodic/texts.py:42, in Text.set_meter(self, **meter_kwargs)
#      40 def set_meter(self, **meter_kwargs):
#      41     from .meter import Meter
# ---> 42     self._mtr = meter = Meter(**meter_kwargs)
#      43     return meter
#
# File ~/github/prosodic/notebooks/../prosodic/meter.py:15, in Meter.__init__(self, constraints, categorical_constraints, max_s, max_w, resolve_optionality)
#       8 def __init__(self,
#       9         constraints=DEFAULT_CONSTRAINTS,
#      10         categorical_constraints=DEFAULT_CATEGORICAL_CONSTRAINTS,
#    (...)
#      13         resolve_optionality=METER_RESOLVE_OPTIONALITY,
#      14         ):
# ---> 15     from .constraints import CONS
#      16     self.constraints = [
#      17         x for x in [
#      18             CONSTRAINTS.get(cname) if type(cname)==str else cname
#      19             for cname in constraints
#      20         ] if x is not None
#      21     ]
#      22     self.categorical_constraints = categorical_constraints
#
# ImportError: cannot import name 'CONS' from 'prosodic.constraints' (/Users/ryan/github/prosodic/notebooks/../prosodic/constraints.py)

# %%
line.parse(max_s=1, max_w=1, constraints=('w_peak',))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/ryan/github/prosodic/notebooks/dev_newprosodic8.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/Users/ryan/github/prosodic/notebooks/dev_newprosodic8.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> line.parse(max_s=1, max_w=1, constraints=('w_peak',))
#
# File ~/github/prosodic/notebooks/../prosodic/meter.py:66, in ParseableText.parse(self, progress, bound, **meter_kwargs)
#      62 @cache
#      63 # @profile
#      64 def parse(self, progress=None, bound=True, **meter_kwargs):
#      65     from .parsing import ParseList
# ---> 66     self.set_meter(**meter_kwargs)
#      67     parses = list(self.iter_parses(progress=progress))
#      68     if bound: self.bound_parses(parses, progress=progress)
#
# File ~/github/prosodic/notebooks/../prosodic/texts.py:42, in Text.set_meter(self, **meter_kwargs)
#      40 def set_meter(self, **meter_kwargs):
#      41     from .meter import Meter
# ---> 42     self._mtr = meter = Meter(**meter_kwargs)
#      43     return meter
#
# File ~/github/prosodic/notebooks/../prosodic/meter.py:15, in Meter.__init__(self, constraints, categorical_constraints, max_s, max_w, resolve_optionality)
#       8 def __init__(self,
#       9         constraints=DEFAULT_CONSTRAINTS,
#      10         categorical_constraints=DEFAULT_CATEGORICAL_CONSTRAINTS,
#    (...)
#      13         resolve_optionality=METER_RESOLVE_OPTIONALITY,
#      14         ):
# ---> 15     self.constraints = [CONSTRAINTS[cname] if type(cname)==str else cname for cname in constraints]
#      16     self.categorical_constraints = categorical_constraints
#      17     self.max_s=max_s
#
# File ~/github/prosodic/notebooks/../prosodic/meter.py:15, in <listcomp>(.0)
#       8 def __init__(self,
#       9         constraints=DEFAULT_CONSTRAINTS,
#      10         categorical_constraints=DEFAULT_CATEGORICAL_CONSTRAINTS,
#    (...)
#      13         resolve_optionality=METER_RESOLVE_OPTIONALITY,
#      14         ):
# ---> 15     self.constraints = [CONSTRAINTS[cname] if type(cname)==str else cname for cname in constraints]
#      16     self.categorical_constraints = categorical_constraints
#      17     self.max_s=max_s
#
# NameError: name 'CONSTRAINTS' is not defined

# %%
# line.best_parses
# line.parses

# %%
t=Text(sonnet)
t
# Out:
# Text()

# %%
t.parse(progress=True)
# Out:
# ParseList(num_parses=14, num_all_parses=14)
