# %%
import sys; sys.path.insert(0,'..')
from prosodic import *

# %%
t=TextModel(sonnet)
t.sents
# Out:
# SentenceList([
#     Sentence([
#         WordToken(num=1, txt='Those', lang='en', para_num=1, line_num=1, sent_num=1, sentpart_num=1, linepart_num=1),
#         WordToken(num=2, txt=' hours', lang='en', para_num=1, line_num=1, sent_num=1, sentpart_num=1, linepart_num=1),
#         WordToken(num=3, txt=',', lang='en', para_num=1, line_num=1, sent_num=1, sentpart_num=1, linepart_num=1, is_punc=1),
#         WordToken(num=4, txt=' that', lang='en', para_num=1, line_num=1, sent_num=1, sentpart_num=2, linepart_num=2),
#         WordToken(num=5, txt=' with', lang='en', para_num=1, line_num=1, sent_num=1, sentpart_num=2, linepart_num=2),
#         WordToken(num=6, txt=' gentle', lang='en', para_num=1, line_num=1, sent_num=1, sentpart_num=2, linepart_num=2),
#         WordToken(num=7, txt=' work', lang='en', para_num=1, line_num=1, sent_num=1, sentpart_num=2, linepart_num=2),
# ...

# %%
t.sents[0].grid
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/github/prosodic/.venv/lib/python3.10/site-packages/IPython/core/formatters.py:347, in BaseFormatter.__call__(self, obj)
#     345     method = get_real_method(obj, self.print_method)
#     346     if method is not None:
# --> 347         return method()
#     348     return None
#     349 else:
#
# File ~/github/prosodic/notebooks/../prosodic/sents/grids.py:55, in SentenceGrid._repr_html_(self)
#      54 def _repr_html_(self):
# ---> 55     return self.plot()
#
# File ~/github/prosodic/notebooks/../prosodic/sents/grids.py:36, in SentenceGrid.plot(self, x, y, label, **kwargs)
#      34 from plotnine import ggplot, aes, geom_col, geom_text, theme_void, options
#      35 options.figure_size = (11, 5)
# ---> 36 figdf = self.df.reset_index()[[x, y, label]]
#      37 figdf[y] = figdf[y] + abs(figdf[y].min()) + 1
# ...
