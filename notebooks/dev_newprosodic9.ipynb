# %%
# !rm -rf /Users/ryan/prosodic_data/data/english_wordtypes
import sys; sys.path.insert(0,'..')
from prosodic.imports import *

# %%
Word('pity')
# Out:
# WordType(txt='pity', lang='en', num_forms=1)

# %%
from IPython.display import HTML
HTML("""
<style>
.violation { color:red; }
</style>
""")
# Out:
# <style>
# .violation { color:red; }
# </style>

# %%
l=Line("Feed'st thy light'st flame with self substantial fuel")

# %%
l.best_parses
# Out:
# 2023-10-07 16:29:35.507 | parse | [None, True, None, {}] | meter.py:74
# 2023-10-07 16:29:35.507 | set_meter | Set meter to: Meter(constraints=('w_peak', 'w_stress', 's_unstress', 'unres_across', 'unres_within'), categorical_constraints=(), max_s=2, max_w=2, resolve_optionality=True) | texts.py:52
# 2023-10-07 16:29:35.508 | iter_parses | [None, Meter(constraints=('w_peak', 'w_stress', 's_unstress', 'unres_across', 'unres_within'), categorical_constraints=(), max_s=2, max_w=2, resolve_optionality=True), {}] | meter.py:88
# 2023-10-07 16:29:35.512 | iter_parses | Generated 466 from a wordfrom matrix of size (2, FEED'ST thy LIGHT'ST FLAME with SELF subs.TAN.tial FUEL, 10, 2, 2, 178) | meter.py:100
# 2023-10-07 16:29:35.612 | iter_parses | Returning 466 parses | meter.py:105
# 2023-10-07 16:29:35.613 | parse | Returned 466 parses | meter.py:77
# 2023-10-07 16:29:35.614 | bound_parses | Bounding 466 with meter Meter(constraints=('w_peak', 'w_stress', 's_unstress', 'unres_across', 'unres_within'), categorical_constraints=(), max_s=2, max_w=2, resolve_optionality=True) | meter.py:115
# ParseList(num_parses=4, num_all_parses=4)
